# %% [markdown]
# #Description

# %% [markdown]
# In this notebook we dealt with the mixed_pataset resulting from the spliting of the original dataset previously to deal with each similar cases in the same way
# This notebook focuses on processing and filtering activity suggestions and commercial activities from a mixed-language dataset (Arabic and French where users enetered both french and arabic languages in the same cell )and matching them with an official activity list. The workflow includes:
#
# 🔹 Data Loading & Preprocessing
#
# Load the mixed dataset and the official activity list.
# Detect the dominant language for each activity.
# Normalize and clean text for both Arabic and French.
#
# 🔹 Embedding Generation
#
# multiple methodologies have been iplemented:
#
# Generate text embeddings using multilingual transformer models:
#
# *   French: paraphrase-multilingual-MiniLM-L12-v2
# *   Arabic: CAMeL-BERT.
#
# but the final version includes:
#
# *   Generate text embeddings using Alibaba-NLP/gte-multilingual-base for both french and arabic.
#
# 🔹 Activity Matching
#
# Compute cosine similarity between embeddings.
# Assign the best-matching activity if similarity exceeds a threshold.
#
# 🔹 Results & Export
#
# Save matched activities to a separate file.
# Save unmatched activities for further review.
# This process ensures a structured and automated approach to classifying suggested activities while handling multilingual data efficiently.
#
# 🔹 Filtering Traditional Commercial Activities:
#
# A predefined list of common commercial activities is compared using semantic similarity.
# Activities classified as traditional commercial (e.g., retail, food services, import/export) are excluded.
# E-commerce & digital intermediary activities are retained for further review.
# Final Output & Categorization:
#
# The system generates three output files:
#
# *   Matched Activities → Successfully mapped to official records.
# *   Not Matched Activities → Unmatched activities for further review.
# *   Filtered Non-Commercial Activities → Excludes traditional commercial
# activities while keeping innovative ones.
#
# This version ensures high accuracy, faster processing, and refined classification, making it an efficient solution for structured activity categorization.

# %%
# !pip install pandas langdetect openpyxl
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: langdetect in /usr/local/lib/python3.11/dist-packages (1.0.9)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.11/dist-packages (3.1.5)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from langdetect) (1.17.0)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.11/dist-packages (from openpyxl) (2.0.0)

# %% [markdown]
# #MIXED DATASET

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## preprocessing

# %%
file_path = '/content/drive/My Drive/DATASET SPLIT/proposition_MIXED.xlsx'  # Update this path
df_mixed = pd.read_excel(file_path)

# Step 3: Display the first few rows of the DataFrame
print(df_mixed.head())
# Out:
#    code_pro   wilaya                                 field  \
# 0  NFL77K67  Mascara  Services de loisirs et de récréation
# 1  YEY4MTKN  Ouargla                Services à la personne
# 2  DKVFC9X8  Algiers                                   NaN
# 3  7YCMDUFE  Algiers                Services à la personne
# 4  AXPQB8GL    Msila                Prestations à domicile
#
#                 activity                                        description
# 0         كهرباء معمارية                                                NaN
# 1                  نجارة   Fabrication de cuisines et chambres modernes MDF
# 2               TOURISME                                                NaN
# 3           Garde malade                                                NaN
# 4  كل أعمال الجبس الفنية  الأشغال الصغيرة للبناء والدهن \nحرفي جباس  \nك...

# %%
df_mixed
# Out:
#       code_pro          wilaya                                 field  \
# 0     NFL77K67         Mascara  Services de loisirs et de récréation
# 1     YEY4MTKN         Ouargla                Services à la personne
# 2     DKVFC9X8         Algiers                                   NaN
# 3     7YCMDUFE         Algiers                Services à la personne
# 4     AXPQB8GL           Msila                Prestations à domicile
# ...        ...             ...                                   ...
# 3403  1DF55VKL           Batna              Services aux entreprises
# 3404  SSFAZK3P  Sidi Bel Abbes                Services à la personne
# 3405  WG8K44WD          Guelma              Services aux entreprises
# 3406  MBQNVBK2          Bouira       Conseil, Expertise et formation
# 3407  BEB2S8T8          Bouira              Services aux entreprises
#
#                                                activity  \
# 0                                        كهرباء معمارية
# 1                                                 نجارة
# 2                                              TOURISME
# 3                                          Garde malade
# 4                                 كل أعمال الجبس الفنية
# ...                                                 ...
# 3403                       Menuiseries aluminium et pvc
# 3404                              صانع عصائر و مشروبات
# 3405                      مكتب دراسات تقنية هندسة مدنية
# 3406  Expertise en Génie Civil, Ingénieur en Génie C...
# 3407  Ingénieur en Génie Civil, Etude des structures...
#
#                                             description
# 0                                                   NaN
# 1      Fabrication de cuisines et chambres modernes MDF
# 2                                                   NaN
# 3                                                   NaN
# 4     الأشغال الصغيرة للبناء والدهن \nحرفي جباس  \nك...
# ...                                                 ...
# 3403                نجارة الألمنيوم والمواد البلاستيكية
# 3404         صانع عصائر و  مشروبات في المطاعم و المقاهي
# 3405  دراسات تقنية في مجال الهندسة المدينة\n-متابعة ...
# 3406                                                NaN
# 3407                                                NaN
#
# [3408 rows x 5 columns]

# %%
# Install necessary libraries
# !pip install langdetect
# !pip install sentence-transformers
# Out:
# Requirement already satisfied: langdetect in /usr/local/lib/python3.11/dist-packages (1.0.9)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from langdetect) (1.17.0)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.11/dist-packages (3.4.1)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.48.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (2.5.1+cu124)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (0.28.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (11.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2024.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.5)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2025.1.31)

# %%
# !pip install unidecode
# Out:
# Requirement already satisfied: unidecode in /usr/local/lib/python3.11/dist-packages (1.3.8)

# %%
import pandas as pd
import torch
from transformers import AutoTokenizer, AutoModel
from sentence_transformers import SentenceTransformer
import numpy as np
import re
from unidecode import unidecode
from sklearn.metrics.pairwise import cosine_similarity
from langdetect import detect

# %% [markdown]
# # using camel bert

# %%
# Load separate models for French and Arabic
model_fr = SentenceTransformer('paraphrase-multilingual-MiniLM-L12-v2')  # Example model for French
arabic_tokenizer = AutoTokenizer.from_pretrained("CAMeL-Lab/bert-base-arabic-camelbert-msa")
arabic_model = AutoModel.from_pretrained("CAMeL-Lab/bert-base-arabic-camelbert-msa")
# Out:
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/4.12k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/645 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/471M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/480 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# 1_Pooling%2Fconfig.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/86.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/468 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/305k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/439M [00:00<?, ?B/s]

# %%
def generate_arabic_embedding(text):
    tokens = arabic_tokenizer(text, return_tensors="pt", padding=True, truncation=True, max_length=512)
    with torch.no_grad():
        outputs = arabic_model(**tokens)
    cls_embedding = outputs.last_hidden_state[:, 0, :].squeeze().numpy()  # Use CLS token representation
    return cls_embedding

    # Step 2: Concatenate activity and description
df_mixed['combined_text'] = df_mixed['activity'] + " " + df_mixed['description']

# Step 3: Function to detect the dominant language
def detect_dominant_language(text):
    languages = []
    try:
        for word in text.split():
            lang = detect(word)
            languages.append(lang)
    except:
        return None
    # Return the most common language detected
    return max(set(languages), key=languages.count)

# Apply language detection
df_mixed['dominant_language'] = df_mixed['combined_text'].apply(detect_dominant_language)
# Out:
# model.safetensors:   0%|          | 0.00/439M [00:00<?, ?B/s]

# %%
# Step 4: Preprocessing function
# Function to normalize Arabic text
def normalize_arabic(text):
    text = re.sub(r'[\u064B-\u065F]', '', text)  # Remove Arabic diacritics
    text = text.replace("أ", "ا").replace("إ", "ا").replace("آ", "ا")  # Normalize Alef variations
    text = text.replace("ة", "ه")  # Normalize Ta Marbuta
    text = text.replace("ى", "ي")  # Normalize Alef Maksura
    text = re.sub(r'[^\w\s]', '', text)  # Remove punctuation
    text = re.sub(r'\s+', ' ', text).strip()  # Remove extra spaces
    return text

# Modified normalization function
def normalize_text(text, lang):
    if not isinstance(text, str) or text.strip() == "":
        return ""
    text = text.lower().strip()
    if lang == "ar":
        text = normalize_arabic(text)  # Apply Arabic-specific preprocessing
    else:
        text = unidecode(text)  # Use Unidecode for French text
    text = re.sub(r'\d+', '', text)  # Remove digits
    return text


# Apply preprocessing based on detected language
df_mixed['processed_text'] = df_mixed.apply(lambda row: normalize_text(row['combined_text'], row['dominant_language']), axis=1)

# Step 5: Generate embeddings for the processed text using the appropriate model
def generate_embeddings(row):
    if row['dominant_language'] == 'fr':
        return model_fr.encode(row['processed_text'])  # Use SentenceTransformer for French
    elif row['dominant_language'] == 'ar':
        return generate_arabic_embedding(row['processed_text'])  # Use CAMeL-BERT for Arabic
    return None

df_mixed['embeddings'] = df_mixed.apply(generate_embeddings, axis=1)

# %%
df_activities = pd.read_excel('/content/drive/My Drive/hackathon1/activities-hackathon/activity_list.xlsx')
 #Step 6: Process activity list based on language
# Apply the same for official activity lists
df_activities['processed_french'] = df_activities['name_activity'].apply(lambda x: normalize_text(x, 'fr'))
df_activities['processed_arabic'] = df_activities['ar_name_activity'].apply(lambda x: normalize_text(x, 'ar'))

# Generate embeddings for both French and Arabic official activities using the appropriate model
df_activities['french_embedding'] = df_activities['processed_french'].apply(lambda x: model_fr.encode(x))
df_activities['arabic_embedding'] = df_activities['processed_arabic'].apply(lambda x: generate_arabic_embedding(x))  # Use the defined function

# Step 7: Matching function based on dominant language
# Step 7: Matching function based on dominant language
def find_match(row):
    if row['dominant_language'] == 'fr':
        similarities = df_activities['french_embedding'].apply(lambda x: cosine_similarity([row['embeddings']], [x])[0][0])
        max_similarity = similarities.max()
        if max_similarity >= 0.6:
            best_match = df_activities.iloc[similarities.idxmax()]
            return best_match['name_activity'], best_match['code_activity']

    elif row['dominant_language'] == 'ar':
        similarities = df_activities['arabic_embedding'].apply(lambda x: cosine_similarity([row['embeddings']], [x])[0][0])
        max_similarity = similarities.max()
        if max_similarity >= 0.6:
            best_match = df_activities.iloc[similarities.idxmax()]
            return best_match['ar_name_activity'], best_match['code_activity']

    return None, None

# Apply matching function
df_mixed[['matched_activity', 'matched_code']] = df_mixed.apply(lambda row: pd.Series(find_match(row)), axis=1)

# Step 8: Save the results
df_mixed.to_excel('/content/drive/My Drive/hackathon1/matched_activities.xlsx', index=False)

# Display some results
print(df_mixed[['combined_text', 'dominant_language', 'processed_text', 'matched_activity', 'matched_code']].head())

# %%
# Filter rows where a match was found
df_matched = df_mixed[df_mixed['matched_activity'].notna() & df_mixed['matched_code'].notna()]

# Print matched rows
print(df_matched[['combined_text', 'dominant_language', 'matched_activity', 'matched_code']])

# Filter matched rows
df_matched = df_mixed[df_mixed['matched_activity'].notna() & df_mixed['matched_code'].notna()]

# Save to a separate file
matched_file_path = "/content/drive/My Drive/hackathon1/matched_activities_only.xlsx"
df_matched.to_excel(matched_file_path, index=False)

print(f"Matched activities saved to: {matched_file_path}")

# Filter rows where NO match was found
df_not_matched = df_mixed[df_mixed['matched_activity'].isna() | df_mixed['matched_code'].isna()]

# Save unmatched rows to a separate file
not_matched_file_path = "/content/drive/My Drive/hackathon1/not_matched_activities.xlsx"
df_not_matched.to_excel(not_matched_file_path, index=False)

print(f"Unmatched activities saved to: {not_matched_file_path}")

# %% [markdown]
# # using alibaba

# %%
import pandas as pd
import torch
from transformers import AutoTokenizer, AutoModel
from sentence_transformers import SentenceTransformer
import numpy as np
import re
from unidecode import unidecode
from sklearn.metrics.pairwise import cosine_similarity
from langdetect import detect

# Load separate models for French and Arabic
model_fr = SentenceTransformer('paraphrase-multilingual-MiniLM-L12-v2')  # Example model for French
model_ar = SentenceTransformer("Alibaba-NLP/gte-multilingual-base", trust_remote_code=True)

# Step 2: Concatenate activity and description
df_mixed['combined_text'] = df_mixed['activity'] + " " + df_mixed['description']

# Step 3: Function to detect the dominant language
def detect_dominant_language(text):
    languages = []
    try:
        for word in text.split():
            lang = detect(word)
            languages.append(lang)
    except:
        return None
    return max(set(languages), key=languages.count)

# Apply language detection
df_mixed['dominant_language'] = df_mixed['combined_text'].apply(detect_dominant_language)

# Step 4: Preprocessing function
def normalize_arabic(text):
    text = re.sub(r'[\u064B-\u065F]', '', text)  # Remove Arabic diacritics
    text = text.replace("أ", "ا").replace("إ", "ا").replace("آ", "ا")  # Normalize Alef variations
    text = text.replace("ة", "ه")  # Normalize Ta Marbuta
    text = text.replace("ى", "ي")  # Normalize Alef Maksura
    text = re.sub(r'[^\w\s]', '', text)  # Remove punctuation
    text = re.sub(r'\s+', ' ', text).strip()  # Remove extra spaces
    return text

def normalize_text(text, lang):
    if not isinstance(text, str) or text.strip() == "":
        return ""
    text = text.lower().strip()
    if lang == "ar":
        text = normalize_arabic(text)
    else:
        text = unidecode(text)
    text = re.sub(r'\d+', '', text)  # Remove digits
    return text

# Apply preprocessing
df_mixed['processed_text'] = df_mixed.apply(lambda row: normalize_text(row['combined_text'], row['dominant_language']), axis=1)

# Step 5: Generate embeddings for the processed text using the appropriate model
def generate_embeddings(row):
    if row['dominant_language'] == 'fr':
        return model_fr.encode(row['processed_text'])
    elif row['dominant_language'] == 'ar':
        return model_ar.encode(row['processed_text'])  # Using Alibaba GTE model
    return None

df_mixed['embeddings'] = df_mixed.apply(generate_embeddings, axis=1)

# Load official activity list
df_activities = pd.read_excel('/content/drive/My Drive/hackathon1/activities-hackathon/activity_list.xlsx')

df_activities['processed_french'] = df_activities['name_activity'].apply(lambda x: normalize_text(x, 'fr'))
df_activities['processed_arabic'] = df_activities['ar_name_activity'].apply(lambda x: normalize_text(x, 'ar'))

df_activities['french_embedding'] = df_activities['processed_french'].apply(lambda x: model_fr.encode(x))
df_activities['arabic_embedding'] = df_activities['processed_arabic'].apply(lambda x: model_ar.encode(x))

# %%
# Step 7: Matching function
def find_match(row):
    if row['dominant_language'] == 'fr':
        similarities = df_activities['french_embedding'].apply(lambda x: cosine_similarity([row['embeddings']], [x])[0][0])
    elif row['dominant_language'] == 'ar':
        similarities = df_activities['arabic_embedding'].apply(lambda x: cosine_similarity([row['embeddings']], [x])[0][0])
    else:
        return None, None

    max_similarity = similarities.max()
    if max_similarity >= 0.7:
        best_match = df_activities.iloc[similarities.idxmax()]
        return best_match['name_activity'] if row['dominant_language'] == 'fr' else best_match['ar_name_activity'], best_match['code_activity']

    return None, None

# Apply matching function
df_mixed[['matched_activity', 'matched_code']] = df_mixed.apply(lambda row: pd.Series(find_match(row)), axis=1)

# Step 8: Save the results
df_mixed.to_excel('/content/drive/My Drive/hackathon1/matched_activities.xlsx', index=False)

# Display some results
print(df_mixed[['combined_text', 'dominant_language', 'processed_text', 'matched_activity', 'matched_code']].head())

# Filter rows where a match was found
df_matched = df_mixed[df_mixed['matched_activity'].notna() & df_mixed['matched_code'].notna()]

# Print matched rows
print(df_matched[['combined_text', 'dominant_language', 'matched_activity', 'matched_code']])

# Filter matched rows
df_matched = df_mixed[df_mixed['matched_activity'].notna() & df_mixed['matched_code'].notna()]

# Save to a separate file
matched_file_path = "/content/drive/My Drive/hackathon1/matched_activities_only.xlsx"
df_matched.to_excel(matched_file_path, index=False)

print(f"Matched activities saved to: {matched_file_path}")

# Filter rows where NO match was found
df_not_matched = df_mixed[df_mixed['matched_activity'].isna() | df_mixed['matched_code'].isna()]

# Save unmatched rows to a separate file
not_matched_file_path = "/content/drive/My Drive/hackathon1/not_matched_activities.xlsx"
df_not_matched.to_excel(not_matched_file_path, index=False)

print(f"Unmatched activities saved to: {not_matched_file_path}")
# Out:
#                                        combined_text dominant_language  \
# 0                                                NaN              None
# 1  نجارة Fabrication de cuisines et chambres mode...                fr
# 2                                                NaN              None
# 3                                                NaN              None
# 4  كل أعمال الجبس الفنية الأشغال الصغيرة للبناء و...                ar
#
#                                       processed_text matched_activity  \
# 0                                                                None
# 1  njr@ fabrication de cuisines et chambres moder...             None
# 2                                                                None
# 3                                                                None
# 4  كل اعمال الجبس الفنيه الاشغال الصغيره للبناء و...             None
#
#    matched_code
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#                                           combined_text dominant_language  \
# 10     سباك أعمال تركيب وصيانة وفحص وتشغيل وإصلاح أن...                ar
# 19    مستشار في تسيير الموارد البشرية تقديم استشارات...                ar
# 34    mécatronique نشاط يشمل كل من المهارات التالية\...                ar
# 42                conducteur vtc ساىق تطبيقات الكترونية                ar
# 47    comptabilité et gestion financière comptabilit...                fr
# ...                                                 ...               ...
# 3378  Ingénieur expert en automatisme, instrumentati...                ar
# 3380  Formateur HSE مدرب ومكون معتمد في مجال الصحة و...                ar
# 3381  Plombier ترصيص و التدفئة المركزية \nتركيب الأن...                ar
# 3388  الطاقات المتجددة كل أعمال استغلال الطاقات المت...                ar
# 3391          تلحيم تلحيم جميع الابواب ونوافذبلازمة cnc                ar
#
#                                        matched_activity  matched_code
# 10                                   قائم تركيب المصاعد       63104.0
# 19                       مساعد في تسيير الموارد البشرية       70104.0
# 34                       تقني متعدد المهام في الميكانيك       61502.0
# 42                                     مشغل خط إلكتروني       61813.0
# 47                          Chargé d'études financières       10615.0
# ...                                                 ...           ...
# 3378  مكلف بالتركيب والتوصيل الكهربائي على المعدات ا...       61809.0
# 3380    مدرب في مكافحة الآفات الحشرية والقوارض والتعقيم       10215.0
# 3381                           مركب – عامل تجميع انابيب       62908.0
# 3388                  تركيب وصيانة أنظمة الطاقة الشمسية       10109.0
# 3391                                      مشغل آلات CNC       10112.0
#
# [374 rows x 4 columns]
# Matched activities saved to: /content/drive/My Drive/hackathon1/matched_activities_only.xlsx
# Unmatched activities saved to: /content/drive/My Drive/hackathon1/not_matched_activities.xlsx

# %% [markdown]
# ## using alibaba for whatever the language is

# %%
# Load the multilingual Alibaba model
model = SentenceTransformer("Alibaba-NLP/gte-multilingual-base", trust_remote_code=True)
# Function to normalize Arabic text
def normalize_arabic(text):
    text = re.sub(r'[\u064B-\u065F]', '', text)  # Remove Arabic diacritics
    text = text.replace("أ", "ا").replace("إ", "ا").replace("آ", "ا")  # Normalize Alef variations
    text = text.replace("ة", "ه")  # Normalize Ta Marbuta
    text = text.replace("ى", "ي")  # Normalize Alef Maksura
    text = re.sub(r'[^\w\s]', '', text)  # Remove punctuation
    text = re.sub(r'\s+', ' ', text).strip()  # Remove extra spaces
    return text

# Function to normalize text (both Arabic & French)
def normalize_text(text):
    if not isinstance(text, str) or text.strip() == "":
        return ""
    text = text.lower().strip()
    if any("\u0600" <= c <= "\u06FF" for c in text):  # Check if Arabic characters exist
        text = normalize_arabic(text)
    else:
        text = unidecode(text)  # Use Unidecode for French
    text = re.sub(r'\d+', '', text)  # Remove digits
    return text

# Apply text normalization
df_mixed['processed_text'] = df_mixed['combined_text'].apply(normalize_text)

# Generate embeddings for all processed text
df_mixed['embeddings'] = df_mixed['processed_text'].apply(lambda x: model.encode(x))

# Load official activity list
df_activities = pd.read_excel('/content/drive/My Drive/hackathon1/activities-hackathon/activity_list.xlsx')

# Normalize official activity names
df_activities['processed_activity'] = df_activities['name_activity'].apply(normalize_text)
df_activities['processed_activity_ar'] = df_activities['ar_name_activity'].apply(normalize_text)

# Generate embeddings for official activities
df_activities['activity_embedding'] = df_activities['processed_activity'].apply(lambda x: model.encode(x))
df_activities['activity_embedding_ar'] = df_activities['processed_activity_ar'].apply(lambda x: model.encode(x))

# Matching function
def find_match(row):
    similarities_fr = df_activities['activity_embedding'].apply(lambda x: cosine_similarity([row['embeddings']], [x])[0][0])
    similarities_ar = df_activities['activity_embedding_ar'].apply(lambda x: cosine_similarity([row['embeddings']], [x])[0][0])

    max_similarity_fr = similarities_fr.max()
    max_similarity_ar = similarities_ar.max()

    # Choose best match from either Arabic or French activities
    if max_similarity_fr >= 0.6 or max_similarity_ar >= 0.6:
        if max_similarity_fr > max_similarity_ar:
            best_match = df_activities.iloc[similarities_fr.idxmax()]
        else:
            best_match = df_activities.iloc[similarities_ar.idxmax()]
        return best_match['name_activity'], best_match['ar_name_activity'], best_match['code_activity']

    return None, None, None

# Apply matching
df_mixed[['matched_activity_fr', 'matched_activity_ar', 'matched_code']] = df_mixed.apply(lambda row: pd.Series(find_match(row)), axis=1)

# Save results
df_mixed.to_excel('/content/drive/My Drive/hackathon1/matched_activities.xlsx', index=False)

print("Matching process completed and saved to Excel.")

# Filter rows where a match was found
df_matched = df_mixed[df_mixed['matched_activity'].notna() & df_mixed['matched_code'].notna()]

# Print matched rows
print(df_matched[['combined_text', 'dominant_language', 'matched_activity', 'matched_code']])

# Filter matched rows
df_matched = df_mixed[df_mixed['matched_activity'].notna() & df_mixed['matched_code'].notna()]

# Save to a separate file
matched_file_path = "/content/drive/My Drive/hackathon1/matched_activities_only.xlsx"
df_matched.to_excel(matched_file_path, index=False)

print(f"Matched activities saved to: {matched_file_path}")

# Filter rows where NO match was found
df_not_matched = df_mixed[df_mixed['matched_activity'].isna() | df_mixed['matched_code'].isna()]

# Save unmatched rows to a separate file
not_matched_file_path = "/content/drive/My Drive/hackathon1/not_matched_activities.xlsx"
df_not_matched.to_excel(not_matched_file_path, index=False)

print(f"Unmatched activities saved to: {not_matched_file_path}")
# Out:
# Some weights of the model checkpoint at Alibaba-NLP/gte-multilingual-base were not used when initializing NewModel: {'classifier.weight', 'classifier.bias'}
# - This IS expected if you are initializing NewModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing NewModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %% [markdown]
# ## optimized

# %%
import pandas as pd
import re
import numpy as np
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
from unidecode import unidecode

# Load the multilingual Alibaba model
model = SentenceTransformer("Alibaba-NLP/gte-multilingual-base", trust_remote_code=True)

# Function to normalize Arabic text
def normalize_arabic(text):
    text = re.sub(r'[\u064B-\u065F]', '', text)  # Remove Arabic diacritics
    text = text.replace("أ", "ا").replace("إ", "ا").replace("آ", "ا")  # Normalize Alef variations
    text = text.replace("ة", "ه")  # Normalize Ta Marbuta
    text = text.replace("ى", "ي")  # Normalize Alef Maksura
    text = re.sub(r'[^\w\s]', '', text)  # Remove punctuation
    text = re.sub(r'\s+', ' ', text).strip()  # Remove extra spaces
    return text

# Function to normalize text (both Arabic & French)
def normalize_text(text):
    if not isinstance(text, str) or text.strip() == "":
        return ""
    text = text.lower().strip()
    if any("\u0600" <= c <= "\u06FF" for c in text):  # Check if Arabic characters exist
        text = normalize_arabic(text)
    else:
        text = unidecode(text)  # Use Unidecode for French
    text = re.sub(r'\d+', '', text)  # Remove digits
    return text

# Step 2: Concatenate activity and description
df_mixed['combined_text'] = df_mixed['activity'] + " " + df_mixed['description']

# Apply text normalization
#df_mixed['processed_text'] = df_mixed['combined_text'].apply(normalize_text)

# Generate embeddings for all processed text
df_mixed['embeddings'] = df_mixed['combined_text'].astype(str).apply(lambda x: model.encode(x) if x.strip() else np.zeros(model.get_sentence_embedding_dimension()))

# Load official activity list
df_activities = pd.read_excel('/content/drive/My Drive/hackathon1/activities-hackathon/activity_list.xlsx')

# Normalize official activity names
# df_activities['processed_activity'] = df_activities['name_activity'].apply(normalize_text)
# df_activities['processed_activity_ar'] = df_activities['ar_name_activity'].apply(normalize_text)

# Generate embeddings for official activities
df_activities['activity_embedding'] = df_activities['name_activity'].astype(str).apply(
    lambda x: model.encode(x) if x.strip() else np.zeros(model.get_sentence_embedding_dimension())
)
df_activities['activity_embedding_ar'] = df_activities['ar_name_activity'].astype(str).apply(
    lambda x: model.encode(x) if x.strip() else np.zeros(model.get_sentence_embedding_dimension())
)

# 🚀 Convert embeddings to NumPy arrays for faster similarity search
activity_embeddings_fr = np.stack(df_activities['activity_embedding'].values)
activity_embeddings_ar = np.stack(df_activities['activity_embedding_ar'].values)

# Step 7: Optimized Matching Function
def find_best_match(row):
    # Compute similarity in bulk
    similarities_fr = cosine_similarity([row['embeddings']], activity_embeddings_fr)[0]
    similarities_ar = cosine_similarity([row['embeddings']], activity_embeddings_ar)[0]

    # Combine all similarities
    all_similarities = np.concatenate((similarities_fr, similarities_ar))

    # Get best match
    best_idx = np.argmax(all_similarities)
    best_similarity = all_similarities[best_idx]

    # Debugging output
    print(f"Best index: {best_idx}, Best similarity: {best_similarity}")

    if best_similarity >= 0.8 and best_idx < len(df_activities):
        best_match = df_activities.iloc[best_idx]
        return best_match['name_activity'], best_match['ar_name_activity'], best_match['code_activity']

    # Ensure we return a tuple of three elements
    return None, None, None

# Check if df_mixed and df_activities are not empty
if not df_mixed.empty and not df_activities.empty:
    # Apply the optimized matching function
    results = df_mixed.apply(find_best_match, axis=1)

    # Ensure results is a DataFrame
    df_results = pd.DataFrame(results.tolist(), columns=['matched_activity', 'matched_activity_ar', 'matched_code'])

    # Assign the results back to df_mixed
    df_mixed[['matched_activity', 'matched_activity_ar', 'matched_code']] = df_results

    # Save results
    df_mixed.to_excel('/content/drive/My Drive/hackathon1/matched_activities.xlsx', index=False)
    print("Matching process completed and saved to Excel.")

    # Filter rows where a match was found
    df_matched = df_mixed[df_mixed['matched_activity'].notna() & df_mixed['matched_code'].notna()]

    # Print matched rows
    print(df_matched[['combined_text', 'matched_activity', 'matched_activity_ar', 'matched_code']])

    # Save matched rows to a separate file
    matched_file_path = "/content/drive/My Drive/hackathon1/matched_activities_only.xlsx"
    df_matched.to_excel(matched_file_path, index=False)
    print(f"Matched activities saved to: {matched_file_path}")

    # Filter rows where NO match was found
    df_not_matched = df_mixed[df_mixed['matched_activity'].isna() | df_mixed['matched_code'].isna()]

    # Save unmatched rows to a separate file
    not_matched_file_path = "/content/drive/My Drive/hackathon1/not_matched_activities.xlsx"
    df_not_matched.to_excel(not_matched_file_path, index=False)
    print(f"Unmatched activities saved to: {not_matched_file_path}")
else:
    print("No data to process. Please check the input DataFrames.")
# Out:
# Some weights of the model checkpoint at Alibaba-NLP/gte-multilingual-base were not used when initializing NewModel: {'classifier.weight', 'classifier.bias'}
# - This IS expected if you are initializing NewModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing NewModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Best index: 2910, Best similarity: 1.0
# Best index: 1617, Best similarity: 0.6400606632232666
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 6, Best similarity: 0.683967649936676
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 1910, Best similarity: 0.7536624670028687
# Best index: 2910, Best similarity: 1.0
# Best index: 554, Best similarity: 0.6077630519866943
# Best index: 2910, Best similarity: 1.0
# Best index: 6, Best similarity: 0.6833605766296387
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2843, Best similarity: 0.8458501696586609
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2672, Best similarity: 0.6912565231323242
# Best index: 2910, Best similarity: 1.0
# Best index: 1363, Best similarity: 0.5889149904251099
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2163, Best similarity: 0.7721092700958252
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 171, Best similarity: 0.6488277912139893
# Best index: 2910, Best similarity: 1.0
# Best index: 695, Best similarity: 0.7361105680465698
# Best index: 2910, Best similarity: 1.0
# Best index: 1365, Best similarity: 0.8391435146331787
# Best index: 2910, Best similarity: 1.0
# Best index: 2909, Best similarity: 0.76120525598526
# Best index: 1207, Best similarity: 0.713699996471405
# Best index: 2910, Best similarity: 1.0
# Best index: 897, Best similarity: 0.7848995923995972
# Best index: 362, Best similarity: 0.6455327272415161
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2235, Best similarity: 0.6487231850624084
# Best index: 2910, Best similarity: 1.0
# Best index: 1845, Best similarity: 0.7355047464370728
# Best index: 1425, Best similarity: 0.7083576917648315
# Best index: 255, Best similarity: 0.6364565491676331
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2586, Best similarity: 0.8327754735946655
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2656, Best similarity: 0.5984531044960022
# Best index: 1429, Best similarity: 0.6334452629089355
# Best index: 1385, Best similarity: 0.712052047252655
# Best index: 2910, Best similarity: 1.0
# Best index: 571, Best similarity: 0.6325843334197998
# Best index: 2355, Best similarity: 0.7365686893463135
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2842, Best similarity: 0.6695411205291748
# Best index: 2910, Best similarity: 1.0
# Best index: 853, Best similarity: 0.7239477038383484
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 1208, Best similarity: 0.6085081696510315
# Best index: 2910, Best similarity: 1.0
# Best index: 491, Best similarity: 0.7592384219169617
# Best index: 2910, Best similarity: 1.0
# Best index: 641, Best similarity: 0.6329764723777771
# Best index: 2910, Best similarity: 1.0
# Best index: 2827, Best similarity: 0.553764820098877
# Best index: 2348, Best similarity: 0.6859441995620728
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 1564, Best similarity: 0.6727519035339355
# Best index: 2910, Best similarity: 1.0
# Best index: 2871, Best similarity: 0.6948813199996948
# Best index: 2910, Best similarity: 1.0
# Best index: 1931, Best similarity: 0.677941620349884
# Best index: 919, Best similarity: 0.6725937128067017
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 552, Best similarity: 0.8381288647651672
# Best index: 2910, Best similarity: 1.0
# Best index: 2871, Best similarity: 0.6810174584388733
# Best index: 2353, Best similarity: 0.6446377038955688
# Best index: 2910, Best similarity: 1.0
# Best index: 824, Best similarity: 0.6756248474121094
# Best index: 2910, Best similarity: 1.0
# Best index: 2903, Best similarity: 0.6968151330947876
# Best index: 2002, Best similarity: 0.6064620018005371
# Best index: 2920, Best similarity: 0.6040220856666565
# Best index: 2910, Best similarity: 1.0
# Best index: 2823, Best similarity: 0.6925544738769531
# Best index: 2905, Best similarity: 0.5970699787139893
# Best index: 2910, Best similarity: 1.0
# Best index: 2919, Best similarity: 0.7794294357299805
# Best index: 2362, Best similarity: 0.6612539887428284
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 1845, Best similarity: 0.7596710920333862
# Best index: 853, Best similarity: 0.742401123046875
# Best index: 2910, Best similarity: 1.0
# Best index: 2483, Best similarity: 0.8057847023010254
# Best index: 1875, Best similarity: 0.626308262348175
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 1847, Best similarity: 0.6821539998054504
# Best index: 213, Best similarity: 0.6415205001831055
# Best index: 2324, Best similarity: 0.7449499368667603
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 1424, Best similarity: 0.6265612840652466
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2356, Best similarity: 0.5429240465164185
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2349, Best similarity: 0.7001951336860657
# Best index: 1443, Best similarity: 0.6327815055847168
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2589, Best similarity: 0.6883130669593811
# Best index: 2358, Best similarity: 0.5740751028060913
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 620, Best similarity: 0.5822644829750061
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 776, Best similarity: 0.7655019164085388
# Best index: 1443, Best similarity: 0.7641846537590027
# Best index: 2910, Best similarity: 1.0
# Best index: 1946, Best similarity: 0.6565293669700623
# Best index: 552, Best similarity: 0.8889030814170837
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 911, Best similarity: 0.8103541135787964
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2893, Best similarity: 0.7562907338142395
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2364, Best similarity: 0.7035095691680908
# Best index: 2910, Best similarity: 1.0
# Best index: 2382, Best similarity: 0.8480368852615356
# Best index: 1546, Best similarity: 0.6460355520248413
# Best index: 2910, Best similarity: 1.0
# Best index: 1617, Best similarity: 0.6429063081741333
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 1486, Best similarity: 0.6277276277542114
# Best index: 2910, Best similarity: 1.0
# Best index: 2879, Best similarity: 0.5848752856254578
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 1810, Best similarity: 0.624485969543457
# Best index: 973, Best similarity: 0.7424800395965576
# Best index: 1957, Best similarity: 0.6250706911087036
# Best index: 2910, Best similarity: 1.0
# Best index: 1492, Best similarity: 0.6854571104049683
# Best index: 2910, Best similarity: 1.0
# Best index: 2890, Best similarity: 0.6812705993652344
# Best index: 1723, Best similarity: 0.6461055278778076
# Best index: 1523, Best similarity: 0.5942882895469666
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2858, Best similarity: 0.623911440372467
# Best index: 2910, Best similarity: 1.0
# Best index: 1957, Best similarity: 0.7120658755302429
# Best index: 1077, Best similarity: 0.8008743524551392
# Best index: 2628, Best similarity: 0.81117182970047
# Best index: 2910, Best similarity: 1.0
# Best index: 1447, Best similarity: 0.8294278383255005
# Best index: 1464, Best similarity: 0.691595196723938
# Best index: 2349, Best similarity: 0.7008616924285889
# Best index: 2910, Best similarity: 1.0
# Best index: 917, Best similarity: 0.6912131309509277
# Best index: 2915, Best similarity: 0.6381396651268005
# Best index: 2910, Best similarity: 1.0
# Best index: 1362, Best similarity: 0.57071453332901
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2907, Best similarity: 0.6155519485473633
# Best index: 920, Best similarity: 0.9305357933044434
# Best index: 2910, Best similarity: 1.0
# Best index: 2344, Best similarity: 0.58488529920578
# Best index: 380, Best similarity: 0.9698909521102905
# Best index: 2838, Best similarity: 0.6390385627746582
# Best index: 2357, Best similarity: 0.7170257568359375
# Best index: 2871, Best similarity: 0.6301337480545044
# Best index: 2672, Best similarity: 0.6070246696472168
# Best index: 2016, Best similarity: 0.8481781482696533
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 1517, Best similarity: 0.6663427352905273
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2136, Best similarity: 0.60419100522995
# Best index: 1440, Best similarity: 0.7269462943077087
# Best index: 344, Best similarity: 0.5774345993995667
# Best index: 2910, Best similarity: 1.0
# Best index: 2453, Best similarity: 0.6739344000816345
# Best index: 2910, Best similarity: 1.0
# Best index: 2405, Best similarity: 0.7317021489143372
# Best index: 2910, Best similarity: 1.0
# Best index: 2907, Best similarity: 0.6655195951461792
# Best index: 2542, Best similarity: 0.7921913862228394
# Best index: 2809, Best similarity: 0.7405143976211548
# Best index: 2635, Best similarity: 0.8259801864624023
# Best index: 1907, Best similarity: 0.7078123092651367
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 1780, Best similarity: 0.8083119988441467
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 474, Best similarity: 0.771458089351654
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2534, Best similarity: 0.7262485027313232
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 1817, Best similarity: 0.7253813743591309
# Best index: 1979, Best similarity: 0.7130756974220276
# Best index: 2361, Best similarity: 0.6949269771575928
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2912, Best similarity: 0.6625398397445679
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 1723, Best similarity: 0.6624176502227783
# Best index: 2910, Best similarity: 1.0
# Best index: 2858, Best similarity: 0.7338376045227051
# Best index: 145, Best similarity: 0.6490558981895447
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 1492, Best similarity: 0.615633487701416
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2893, Best similarity: 0.640699565410614
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 894, Best similarity: 0.6134598255157471
# Best index: 2910, Best similarity: 1.0
# Best index: 64, Best similarity: 0.6758949756622314
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2920, Best similarity: 0.690947949886322
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 469, Best similarity: 0.6366528272628784
# Best index: 1068, Best similarity: 0.6979794502258301
# Best index: 2905, Best similarity: 0.8616631627082825
# Best index: 1535, Best similarity: 0.7120357751846313
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2914, Best similarity: 0.5966699719429016
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 367, Best similarity: 0.640069842338562
# Best index: 1884, Best similarity: 0.8267604112625122
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2159, Best similarity: 0.6477968692779541
# Best index: 2562, Best similarity: 0.6930369138717651
# Best index: 2910, Best similarity: 1.0
# Best index: 2349, Best similarity: 0.723688542842865
# Best index: 2029, Best similarity: 0.6288609504699707
# Best index: 2523, Best similarity: 0.7176182866096497
# Best index: 2913, Best similarity: 0.6415058970451355
# Best index: 2910, Best similarity: 1.0
# Best index: 1569, Best similarity: 0.6901383399963379
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 1957, Best similarity: 0.6645879149436951
# Best index: 2900, Best similarity: 0.6665641665458679
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2748, Best similarity: 0.649482250213623
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 916, Best similarity: 0.659439742565155
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 362, Best similarity: 0.6893242001533508
# Best index: 2672, Best similarity: 0.7028055191040039
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 1753, Best similarity: 0.6883547306060791
# Best index: 2306, Best similarity: 0.6573343276977539
# Best index: 920, Best similarity: 0.8227906227111816
# Best index: 2910, Best similarity: 1.0
# Best index: 2153, Best similarity: 0.7604742050170898
# Best index: 2910, Best similarity: 1.0
# Best index: 521, Best similarity: 0.7621333003044128
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2540, Best similarity: 0.6531840562820435
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2881, Best similarity: 0.7836185097694397
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2871, Best similarity: 0.6199213266372681
# Best index: 56, Best similarity: 0.6014773845672607
# Best index: 2857, Best similarity: 0.6939244270324707
# Best index: 2910, Best similarity: 1.0
# Best index: 2600, Best similarity: 0.6251749992370605
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2672, Best similarity: 0.6927936673164368
# Best index: 914, Best similarity: 0.6708263754844666
# Best index: 1301, Best similarity: 0.822422206401825
# Best index: 2323, Best similarity: 0.6788322925567627
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 1492, Best similarity: 0.6191514730453491
# Best index: 2910, Best similarity: 1.0
# Best index: 1612, Best similarity: 0.6093993782997131
# Best index: 2910, Best similarity: 1.0
# Best index: 2675, Best similarity: 0.7862027883529663
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 1302, Best similarity: 0.6437361240386963
# Best index: 2910, Best similarity: 1.0
# Best index: 2646, Best similarity: 0.824303150177002
# Best index: 481, Best similarity: 0.6655579209327698
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2880, Best similarity: 0.6366319060325623
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 16, Best similarity: 0.5885605812072754
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2541, Best similarity: 0.712970495223999
# Best index: 2675, Best similarity: 0.6304164528846741
# Best index: 1948, Best similarity: 0.6049453616142273
# Best index: 2916, Best similarity: 0.8751775026321411
# Best index: 2910, Best similarity: 1.0
# Best index: 769, Best similarity: 0.7219910621643066
# Best index: 2905, Best similarity: 0.7128136157989502
# Best index: 2364, Best similarity: 0.6298452615737915
# Best index: 2910, Best similarity: 1.0
# Best index: 1443, Best similarity: 0.7041054964065552
# Best index: 2524, Best similarity: 0.631491482257843
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 1948, Best similarity: 0.6138940453529358
# Best index: 1522, Best similarity: 0.6490828990936279
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2808, Best similarity: 0.7956088185310364
# Best index: 635, Best similarity: 0.7119256258010864
# Best index: 2910, Best similarity: 1.0
# Best index: 2920, Best similarity: 0.6028856039047241
# Best index: 2910, Best similarity: 1.0
# Best index: 2634, Best similarity: 0.833845853805542
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 888, Best similarity: 0.6722462773323059
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2864, Best similarity: 0.6632671356201172
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 1641, Best similarity: 0.6382781267166138
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 363, Best similarity: 0.7007912397384644
# Best index: 2910, Best similarity: 1.0
# Best index: 1170, Best similarity: 0.6654143333435059
# Best index: 2353, Best similarity: 0.6259822845458984
# Best index: 1954, Best similarity: 0.7196123600006104
# Best index: 2910, Best similarity: 1.0
# Best index: 1290, Best similarity: 0.664483368396759
# Best index: 2374, Best similarity: 0.6623096466064453
# Best index: 2871, Best similarity: 0.5898473262786865
# Best index: 2832, Best similarity: 0.6143550872802734
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 213, Best similarity: 0.5985746383666992
# Best index: 2873, Best similarity: 0.7120901942253113
# Best index: 2910, Best similarity: 1.0
# Best index: 1870, Best similarity: 0.6296924948692322
# Best index: 781, Best similarity: 0.6754565834999084
# Best index: 2910, Best similarity: 1.0
# Best index: 2287, Best similarity: 0.7465668320655823
# Best index: 1492, Best similarity: 0.6695157289505005
# Best index: 2910, Best similarity: 1.0
# Best index: 2323, Best similarity: 0.6623398065567017
# Best index: 1523, Best similarity: 0.5691266655921936
# Best index: 2891, Best similarity: 0.6277449131011963
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 1957, Best similarity: 0.6640963554382324
# Best index: 1870, Best similarity: 0.6496562957763672
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 1033, Best similarity: 0.6873044967651367
# Best index: 2910, Best similarity: 1.0
# Best index: 1907, Best similarity: 0.7763128280639648
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 1288, Best similarity: 0.6443051695823669
# Best index: 2910, Best similarity: 1.0
# Best index: 2357, Best similarity: 0.6046828031539917
# Best index: 1487, Best similarity: 0.6361989378929138
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 1957, Best similarity: 0.6840208768844604
# Best index: 2910, Best similarity: 1.0
# Best index: 2907, Best similarity: 0.6631344556808472
# Best index: 1920, Best similarity: 0.7706218361854553
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2625, Best similarity: 0.7383337020874023
# Best index: 2384, Best similarity: 0.693218469619751
# Best index: 1886, Best similarity: 0.589718222618103
# Best index: 2910, Best similarity: 1.0
# Best index: 2158, Best similarity: 0.6608031988143921
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2558, Best similarity: 0.7865113019943237
# Best index: 1319, Best similarity: 0.6991887092590332
# Best index: 2886, Best similarity: 0.636351466178894
# Best index: 2910, Best similarity: 1.0
# Best index: 2384, Best similarity: 0.6284080147743225
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2175, Best similarity: 0.7237697243690491
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 1492, Best similarity: 0.6890015602111816
# Best index: 2857, Best similarity: 0.6729052662849426
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2920, Best similarity: 0.7176636457443237
# Best index: 2910, Best similarity: 1.0
# Best index: 1111, Best similarity: 0.6642086505889893
# Best index: 2893, Best similarity: 0.708031415939331
# Best index: 920, Best similarity: 0.7989330291748047
# Best index: 2910, Best similarity: 1.0
# Best index: 296, Best similarity: 0.7183387279510498
# Best index: 2910, Best similarity: 1.0
# Best index: 668, Best similarity: 0.6725605130195618
# Best index: 2541, Best similarity: 0.741632342338562
# Best index: 2910, Best similarity: 1.0
# Best index: 1384, Best similarity: 0.7142379283905029
# Best index: 1464, Best similarity: 0.734000563621521
# Best index: 2910, Best similarity: 1.0
# Best index: 1473, Best similarity: 0.6566929817199707
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 905, Best similarity: 0.7691503167152405
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 54, Best similarity: 0.7732565999031067
# Best index: 1726, Best similarity: 0.672116219997406
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 576, Best similarity: 0.6388117074966431
# Best index: 2910, Best similarity: 1.0
# Best index: 902, Best similarity: 0.6385098099708557
# Best index: 2592, Best similarity: 0.6251598596572876
# Best index: 2820, Best similarity: 0.7121773958206177
# Best index: 1684, Best similarity: 0.8730700612068176
# Best index: 2635, Best similarity: 0.8265560865402222
# Best index: 916, Best similarity: 0.6787185072898865
# Best index: 1884, Best similarity: 0.7174934148788452
# Best index: 2780, Best similarity: 0.6436941623687744
# Best index: 2781, Best similarity: 0.6500083208084106
# Best index: 2910, Best similarity: 1.0
# Best index: 257, Best similarity: 0.7040243148803711
# Best index: 2303, Best similarity: 0.5588688850402832
# Best index: 2358, Best similarity: 0.778830349445343
# Best index: 2864, Best similarity: 0.7654006481170654
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 1689, Best similarity: 0.711165189743042
# Best index: 2601, Best similarity: 0.627950131893158
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2858, Best similarity: 0.6305761337280273
# Best index: 2893, Best similarity: 0.7167114615440369
# Best index: 1367, Best similarity: 0.8835933208465576
# Best index: 1443, Best similarity: 0.6875693798065186
# Best index: 2178, Best similarity: 0.6185928583145142
# Best index: 2346, Best similarity: 0.7888220548629761
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 920, Best similarity: 0.715709388256073
# Best index: 920, Best similarity: 0.744543194770813
# Best index: 920, Best similarity: 0.744543194770813
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 1451, Best similarity: 0.600481390953064
# Best index: 2384, Best similarity: 0.7786657810211182
# Best index: 2064, Best similarity: 0.6207005977630615
# Best index: 2910, Best similarity: 1.0
# Best index: 2597, Best similarity: 0.65993732213974
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2861, Best similarity: 0.761231541633606
# Best index: 2905, Best similarity: 0.7002235651016235
# Best index: 2910, Best similarity: 1.0
# Best index: 1214, Best similarity: 0.6674493551254272
# Best index: 1657, Best similarity: 0.5350040793418884
# Best index: 2910, Best similarity: 1.0
# Best index: 2820, Best similarity: 0.655319094657898
# Best index: 2910, Best similarity: 1.0
# Best index: 2246, Best similarity: 0.7616131901741028
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2600, Best similarity: 0.6342067122459412
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 1403, Best similarity: 0.8172272443771362
# Best index: 2910, Best similarity: 1.0
# Best index: 2373, Best similarity: 0.604988157749176
# Best index: 2883, Best similarity: 0.7820898294448853
# Best index: 2303, Best similarity: 0.6785785555839539
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2594, Best similarity: 0.5857447981834412
# Best index: 2861, Best similarity: 0.6467065811157227
# Best index: 2910, Best similarity: 1.0
# Best index: 1339, Best similarity: 0.6117943525314331
# Best index: 2384, Best similarity: 0.8270171880722046
# Best index: 2910, Best similarity: 1.0
# Best index: 2864, Best similarity: 0.7745258212089539
# Best index: 1164, Best similarity: 0.6336469650268555
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 1312, Best similarity: 0.5614479780197144
# Best index: 2910, Best similarity: 1.0
# Best index: 2384, Best similarity: 0.6602506637573242
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2747, Best similarity: 0.6103184223175049
# Best index: 919, Best similarity: 0.7534544467926025
# Best index: 2910, Best similarity: 1.0
# Best index: 1859, Best similarity: 0.759846568107605
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 1400, Best similarity: 0.7390894889831543
# Best index: 2383, Best similarity: 0.5902374982833862
# Best index: 1535, Best similarity: 0.7806806564331055
# Best index: 2916, Best similarity: 0.7671164870262146
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 1161, Best similarity: 0.6941791772842407
# Best index: 916, Best similarity: 0.6492972373962402
# Best index: 1399, Best similarity: 0.7779654264450073
# Best index: 1208, Best similarity: 0.6103566884994507
# Best index: 2064, Best similarity: 0.6433466672897339
# Best index: 1617, Best similarity: 0.7059834003448486
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 1448, Best similarity: 0.6873146295547485
# Best index: 2872, Best similarity: 0.645872950553894
# Best index: 2910, Best similarity: 1.0
# Best index: 902, Best similarity: 0.6463003158569336
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 641, Best similarity: 0.5957602858543396
# Best index: 2437, Best similarity: 0.679356575012207
# Best index: 2542, Best similarity: 0.6591065526008606
# Best index: 1033, Best similarity: 0.6537531614303589
# Best index: 2436, Best similarity: 0.7202804088592529
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 1455, Best similarity: 0.6855040788650513
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2893, Best similarity: 0.7918274402618408
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 1136, Best similarity: 0.690163254737854
# Best index: 2303, Best similarity: 0.7668886184692383
# Best index: 2910, Best similarity: 1.0
# Best index: 2542, Best similarity: 0.7522562146186829
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 1847, Best similarity: 0.795891523361206
# Best index: 2309, Best similarity: 0.6315975785255432
# Best index: 2910, Best similarity: 1.0
# Best index: 2907, Best similarity: 0.6324690580368042
# Best index: 2910, Best similarity: 1.0
# Best index: 2335, Best similarity: 0.7778825163841248
# Best index: 2910, Best similarity: 1.0
# Best index: 1430, Best similarity: 0.6328451633453369
# Best index: 2910, Best similarity: 1.0
# Best index: 2893, Best similarity: 0.6641323566436768
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 920, Best similarity: 0.6985891461372375
# Best index: 897, Best similarity: 0.6532361507415771
# Best index: 897, Best similarity: 0.6532361507415771
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2580, Best similarity: 0.5874893665313721
# Best index: 1429, Best similarity: 0.6803983449935913
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2898, Best similarity: 0.6640444993972778
# Best index: 2864, Best similarity: 0.6320577263832092
# Best index: 1067, Best similarity: 0.6018571853637695
# Best index: 2374, Best similarity: 0.7025721669197083
# Best index: 1443, Best similarity: 0.6993510723114014
# Best index: 2920, Best similarity: 0.6496890783309937
# Best index: 2910, Best similarity: 1.0
# Best index: 1528, Best similarity: 0.6829807162284851
# Best index: 2361, Best similarity: 0.6058689951896667
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 1788, Best similarity: 0.7355480790138245
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2675, Best similarity: 0.6580058932304382
# Best index: 1869, Best similarity: 0.6867860555648804
# Best index: 2910, Best similarity: 1.0
# Best index: 2129, Best similarity: 0.6394743919372559
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2246, Best similarity: 0.6947109699249268
# Best index: 2818, Best similarity: 0.7253503799438477
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 1850, Best similarity: 0.7065045833587646
# Best index: 1148, Best similarity: 0.7349573373794556
# Best index: 1904, Best similarity: 0.633378267288208
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 524, Best similarity: 0.6353622674942017
# Best index: 531, Best similarity: 0.5717676281929016
# Best index: 2879, Best similarity: 0.6455986499786377
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 1535, Best similarity: 0.723109245300293
# Best index: 2887, Best similarity: 0.6588030457496643
# Best index: 2886, Best similarity: 0.5969929695129395
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 1430, Best similarity: 0.6190119981765747
# Best index: 2137, Best similarity: 0.7264156341552734
# Best index: 2871, Best similarity: 0.6114118099212646
# Best index: 1438, Best similarity: 0.6114516258239746
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 1012, Best similarity: 0.7259773015975952
# Best index: 1446, Best similarity: 0.7175350785255432
# Best index: 2846, Best similarity: 0.6755847334861755
# Best index: 2910, Best similarity: 1.0
# Best index: 2361, Best similarity: 0.5991466045379639
# Best index: 2263, Best similarity: 0.6458720564842224
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 10, Best similarity: 0.7853085994720459
# Best index: 2622, Best similarity: 0.7375731468200684
# Best index: 2893, Best similarity: 0.7009968757629395
# Best index: 894, Best similarity: 0.7220504879951477
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 920, Best similarity: 0.8399805426597595
# Best index: 2910, Best similarity: 1.0
# Best index: 1535, Best similarity: 0.7050257325172424
# Best index: 2304, Best similarity: 0.6022171378135681
# Best index: 2910, Best similarity: 1.0
# Best index: 2766, Best similarity: 0.6919981837272644
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2331, Best similarity: 0.6713039875030518
# Best index: 2910, Best similarity: 1.0
# Best index: 1945, Best similarity: 0.616117000579834
# Best index: 1488, Best similarity: 0.6586122512817383
# Best index: 1312, Best similarity: 0.6899830102920532
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2864, Best similarity: 0.6518562436103821
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 1383, Best similarity: 0.7406736612319946
# Best index: 1441, Best similarity: 0.7765641212463379
# Best index: 2910, Best similarity: 1.0
# Best index: 2299, Best similarity: 0.7485349178314209
# Best index: 730, Best similarity: 0.6797587871551514
# Best index: 2630, Best similarity: 0.6440712213516235
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 1535, Best similarity: 0.6291000843048096
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 328, Best similarity: 0.7959859371185303
# Best index: 2676, Best similarity: 0.6182219982147217
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 578, Best similarity: 0.6270836591720581
# Best index: 2910, Best similarity: 1.0
# Best index: 1535, Best similarity: 0.6789018511772156
# Best index: 2910, Best similarity: 1.0
# Best index: 2180, Best similarity: 0.6251017451286316
# Best index: 2910, Best similarity: 1.0
# Best index: 1203, Best similarity: 0.710016667842865
# Best index: 2616, Best similarity: 0.6537939310073853
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 1450, Best similarity: 0.6812930107116699
# Best index: 2910, Best similarity: 1.0
# Best index: 2361, Best similarity: 0.679684042930603
# Best index: 2361, Best similarity: 0.634210467338562
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 1171, Best similarity: 0.7645126581192017
# Best index: 169, Best similarity: 0.6238381862640381
# Best index: 2404, Best similarity: 0.7892976999282837
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 1621, Best similarity: 0.6297725439071655
# Best index: 2172, Best similarity: 0.7202314138412476
# Best index: 2910, Best similarity: 1.0
# Best index: 2679, Best similarity: 0.6559139490127563
# Best index: 1403, Best similarity: 0.6705315113067627
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2925, Best similarity: 0.7355988025665283
# Best index: 1205, Best similarity: 0.6433510780334473
# Best index: 2643, Best similarity: 0.6158950328826904
# Best index: 52, Best similarity: 0.7274819612503052
# Best index: 2910, Best similarity: 1.0
# Best index: 2884, Best similarity: 0.7954835295677185
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2600, Best similarity: 0.6897751092910767
# Best index: 2600, Best similarity: 0.7042020559310913
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 1724, Best similarity: 0.7008220553398132
# Best index: 2910, Best similarity: 1.0
# Best index: 1443, Best similarity: 0.7307003736495972
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2362, Best similarity: 0.6385826468467712
# Best index: 2326, Best similarity: 0.6918200850486755
# Best index: 916, Best similarity: 0.6760267615318298
# Best index: 141, Best similarity: 0.6298831701278687
# Best index: 2778, Best similarity: 0.697840690612793
# Best index: 2910, Best similarity: 1.0
# Best index: 1995, Best similarity: 0.6327172517776489
# Best index: 2910, Best similarity: 1.0
# Best index: 1448, Best similarity: 0.6040313243865967
# Best index: 2910, Best similarity: 1.0
# Best index: 1813, Best similarity: 0.6868677735328674
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 1957, Best similarity: 0.6270430088043213
# Best index: 417, Best similarity: 0.7177010774612427
# Best index: 2910, Best similarity: 1.0
# Best index: 902, Best similarity: 0.6514820456504822
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2810, Best similarity: 0.7373192310333252
# Best index: 1813, Best similarity: 0.7300844788551331
# Best index: 894, Best similarity: 0.7689844965934753
# Best index: 1911, Best similarity: 0.7768728137016296
# Best index: 1880, Best similarity: 0.5796429514884949
# Best index: 2828, Best similarity: 0.6766678094863892
# Best index: 1425, Best similarity: 0.6632853746414185
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2820, Best similarity: 0.6904373168945312
# Best index: 1444, Best similarity: 0.6236322522163391
# Best index: 145, Best similarity: 0.7157546877861023
# Best index: 145, Best similarity: 0.7157546877861023
# Best index: 920, Best similarity: 0.7899585962295532
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2820, Best similarity: 0.705909252166748
# Best index: 297, Best similarity: 0.6907172203063965
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2848, Best similarity: 0.736391544342041
# Best index: 1613, Best similarity: 0.6605050563812256
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 1279, Best similarity: 0.5947089195251465
# Best index: 1585, Best similarity: 0.636309027671814
# Best index: 2263, Best similarity: 0.6442832946777344
# Best index: 1617, Best similarity: 0.7247546911239624
# Best index: 2763, Best similarity: 0.609952449798584
# Best index: 1066, Best similarity: 0.5472242832183838
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2838, Best similarity: 0.7176225185394287
# Best index: 2260, Best similarity: 0.6763463020324707
# Best index: 2827, Best similarity: 0.631412148475647
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2843, Best similarity: 0.8234431743621826
# Best index: 820, Best similarity: 0.7990534901618958
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2384, Best similarity: 0.7245243787765503
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2762, Best similarity: 0.5928525924682617
# Best index: 2917, Best similarity: 0.767280101776123
# Best index: 2172, Best similarity: 0.661623477935791
# Best index: 1947, Best similarity: 0.5789793729782104
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 175, Best similarity: 0.7263757586479187
# Best index: 2920, Best similarity: 0.6894844770431519
# Best index: 1481, Best similarity: 0.7008699178695679
# Best index: 496, Best similarity: 0.628737211227417
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2374, Best similarity: 0.7394764423370361
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 1233, Best similarity: 0.7460156679153442
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 1394, Best similarity: 0.544376015663147
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2920, Best similarity: 0.6797903776168823
# Best index: 2920, Best similarity: 0.7711323499679565
# Best index: 1589, Best similarity: 0.5784331560134888
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2893, Best similarity: 0.6913014650344849
# Best index: 2910, Best similarity: 1.0
# Best index: 2531, Best similarity: 0.770419180393219
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 1847, Best similarity: 0.7646989226341248
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 1633, Best similarity: 0.6720178127288818
# Best index: 571, Best similarity: 0.6711477041244507
# Best index: 347, Best similarity: 0.6724667549133301
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 1851, Best similarity: 0.7536155581474304
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2160, Best similarity: 0.7136542797088623
# Best index: 2910, Best similarity: 1.0
# Best index: 2093, Best similarity: 0.7648249268531799
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2020, Best similarity: 0.6227322816848755
# Best index: 2922, Best similarity: 0.6005638241767883
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 1068, Best similarity: 0.6426025629043579
# Best index: 2873, Best similarity: 0.6897061467170715
# ...
# Best index: 1068, Best similarity: 0.5655604600906372
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2533, Best similarity: 0.7662360072135925
# Best index: 1553, Best similarity: 0.7341388463973999
# Best index: 2910, Best similarity: 1.0
# Best index: 1617, Best similarity: 0.675704300403595
# Best index: 1957, Best similarity: 0.6488204598426819
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 453, Best similarity: 0.6572338938713074
# Best index: 2542, Best similarity: 0.7095065116882324
# Best index: 2910, Best similarity: 1.0
# Best index: 1018, Best similarity: 0.6684176921844482
# Best index: 1163, Best similarity: 0.7248365879058838
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 1481, Best similarity: 0.7794572114944458
# Best index: 2910, Best similarity: 1.0
# Best index: 1886, Best similarity: 0.574016809463501
# Best index: 1156, Best similarity: 0.6627455949783325
# Best index: 2542, Best similarity: 0.6691578030586243
# Best index: 2910, Best similarity: 1.0
# Best index: 894, Best similarity: 0.6085326075553894
# Best index: 2910, Best similarity: 1.0
# Best index: 2869, Best similarity: 0.6499223113059998
# Best index: 1954, Best similarity: 0.664739191532135
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2672, Best similarity: 0.6509268879890442
# Best index: 1543, Best similarity: 0.7866055965423584
# Best index: 2910, Best similarity: 1.0
# Best index: 894, Best similarity: 0.7053913474082947
# Best index: 351, Best similarity: 0.9758609533309937
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2903, Best similarity: 0.6441304683685303
# Best index: 2910, Best similarity: 1.0
# Best index: 1129, Best similarity: 0.610746443271637
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2875, Best similarity: 0.7351109385490417
# Best index: 2444, Best similarity: 0.5800231695175171
# Best index: 2444, Best similarity: 0.5800231695175171
# Best index: 2910, Best similarity: 1.0
# Best index: 1284, Best similarity: 0.7550985217094421
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2920, Best similarity: 0.6980660557746887
# Best index: 2910, Best similarity: 1.0
# Best index: 122, Best similarity: 0.6055434942245483
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 1078, Best similarity: 0.7704726457595825
# Best index: 2910, Best similarity: 1.0
# Best index: 1680, Best similarity: 0.5951683521270752
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 1815, Best similarity: 0.6896652579307556
# Best index: 1621, Best similarity: 0.9282345771789551
# Best index: 1693, Best similarity: 0.639228343963623
# Best index: 1413, Best similarity: 0.7656549215316772
# Best index: 1887, Best similarity: 0.6226943731307983
# Best index: 229, Best similarity: 0.7357839345932007
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 1641, Best similarity: 0.5853193998336792
# Best index: 328, Best similarity: 0.7634251117706299
# Best index: 2910, Best similarity: 1.0
# Best index: 1450, Best similarity: 0.7014665603637695
# Best index: 1886, Best similarity: 0.5627470016479492
# Best index: 2879, Best similarity: 0.7410281896591187
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 1916, Best similarity: 0.7012670040130615
# Best index: 1225, Best similarity: 0.6803392171859741
# Best index: 2910, Best similarity: 1.0
# Best index: 2675, Best similarity: 0.6388955116271973
# Best index: 1161, Best similarity: 0.79615318775177
# Best index: 2871, Best similarity: 0.7311277389526367
# Best index: 2675, Best similarity: 0.8040779829025269
# Best index: 1397, Best similarity: 0.7783800363540649
# Best index: 1014, Best similarity: 0.589952826499939
# Best index: 2910, Best similarity: 1.0
# Best index: 890, Best similarity: 0.6601496934890747
# Best index: 2910, Best similarity: 1.0
# Best index: 919, Best similarity: 0.7701255083084106
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 769, Best similarity: 0.6966339945793152
# Best index: 2910, Best similarity: 1.0
# Best index: 2473, Best similarity: 0.7235187888145447
# Best index: 2631, Best similarity: 0.8027310371398926
# Best index: 2883, Best similarity: 0.7017757296562195
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2237, Best similarity: 0.6918184161186218
# Best index: 2237, Best similarity: 0.7032291293144226
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 362, Best similarity: 0.6331496238708496
# Best index: 1403, Best similarity: 0.8102153539657593
# Best index: 1134, Best similarity: 0.6878436803817749
# Best index: 1983, Best similarity: 0.700623631477356
# Best index: 2910, Best similarity: 1.0
# Best index: 1824, Best similarity: 0.8226191997528076
# Best index: 1824, Best similarity: 0.8182922005653381
# Best index: 2471, Best similarity: 0.732877254486084
# Best index: 2781, Best similarity: 0.6585873365402222
# Best index: 2910, Best similarity: 1.0
# Best index: 2575, Best similarity: 0.5996096134185791
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 1078, Best similarity: 0.6585665345191956
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2907, Best similarity: 0.7108014822006226
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 148, Best similarity: 0.6334216594696045
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2601, Best similarity: 0.6191339492797852
# Best index: 2910, Best similarity: 1.0
# Best index: 463, Best similarity: 0.7696738243103027
# Best index: 2910, Best similarity: 1.0
# Best index: 1377, Best similarity: 0.8091057538986206
# Best index: 1983, Best similarity: 0.6868388652801514
# Best index: 1645, Best similarity: 0.5815359950065613
# Best index: 276, Best similarity: 0.7246073484420776
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2919, Best similarity: 0.7792408466339111
# Best index: 2910, Best similarity: 1.0
# Best index: 2248, Best similarity: 0.5958917140960693
# Best index: 2227, Best similarity: 0.6665124893188477
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2353, Best similarity: 0.6539478302001953
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Best index: 1134, Best similarity: 0.6912663578987122
# Best index: 1134, Best similarity: 0.7147971391677856
# Best index: 1641, Best similarity: 0.6097036004066467
# Best index: 556, Best similarity: 0.6266595125198364
# Best index: 575, Best similarity: 0.6749826669692993
# Best index: 1022, Best similarity: 0.6647992730140686
# Best index: 2910, Best similarity: 1.0
# Best index: 2910, Best similarity: 1.0
# Matching process completed and saved to Excel.
#                                           combined_text  \
# 44    Voix off  La voix off, ou voix hors champ, est...
# 100   Modeleur sur plâtre صنع الواح جبسية \nتركيب ال...
# 156                Modeleur sur plâtre  صنع الواح جبسية
# 160   social media manager Gère et développe la visi...
# 198     Marketeur e-commerce     Services numériques...
# 201   Styliste Modéliste de chaussures  styliste mod...
# 212   Chauffeur vtc(Voiture de transport avec chauff...
# 215   Technicien d'installation en courant faible Te...
# 345         VTC تقديم خدمة النقل للأشخاص لقضاء حاجياتهم
# 370   aquaculture التربية السمكية و الصيد البحري \nا...
# 572   reporteur multimedia منتج متعدد الوسائط ينتج  ...
# 609   Conseil en investissement  Le conseil en inves...
# 772                         vtc سائق اجرة يعمل بتطبيقات
# 1062  Soins infirmier  a domicile Faire, et pratique...
# 1184  Livreur professionnel موزع محترف موجه للخدمة ف...
# 1198  Blockchain Developer Blockchain smart contract...
# 1219  Expert en Aquaculture Expert en aquaculture 10...
# 1355  Chauffeur vtc ( voiture de transport) Chauffeu...
# 1565              60310 Ingenieur Chimiste en Industrie
# 1639  Technicien polyvalent en mécanique et travail ...
# 1648  Créateur de contenu sur les réseaux …صانع Créa...
# 1649  Créateur de contenu sur les réseaux …صانع Créa...
# 1772  Livraison à domicile / خدمات التوصيل توصيل الط...
# 1773  Livraison à domicile / خدمات التوصيل توصيل الط...
# 1778  Infographisteمصمم مصمم الاعلانات .اللافتات اغل...
# 1840             Chauffeur VTC VTC نرجو تنشيط مجال سائق
# 1944  Représentant(te) commercial(e) - conseil en ma...
# 1952  Monteur vidéo - مركب فيديو تركيب الفيديو بجميع...
# 2051  محلل بيانات Data Analyst محلل بيانات للشركات و...
# 2288  Nutritionniste/أخصائي في التغذية Ils connaisse...
# 2736  Social media manager Social Media Manager (مدي...
# 2806  Charger de la logistique d'une entreprise de l...
# 2981  E-commerçant / تاجر الكتروني بيع وشراء البضائع...
# 3068  Chauffeur VTC (voiture de transport avec chauf...
# 3123  Devlopement du reseaux Blockchain/مطور شبكات ا...
# 3267  Assistant  en gestion du personnel Assistant  ...
# 3351  Expert financier en études et assistance en in...
# 3380  Formateur HSE مدرب ومكون معتمد في مجال الصحة و...
#
#                                        matched_activity  \
# 44                                             Voix off
# 100                                 Modeleur sur plâtre
# 156                                 Modeleur sur plâtre
# 160   Gestionnaire de réseaux sociaux pour des entre...
# 198                                 Analyste e-commerce
# 201                    Styliste Modéliste de chaussures
# 212   Chauffeur VTC (voiture de transport avec chauf...
# 215       Technicien d'installation en courants faibles
# 345   Chauffeur VTC (voiture de transport avec chauf...
# 370                               Expert en aquaculture
# 572                                Reporteur multimédia
# 609                        Conseiller en investissement
# 772   Chauffeur VTC (voiture de transport avec chauf...
# 1062                          Infirmier(ère) à domicile
# 1184  Chargé(e) de la logistique d'une entreprise de...
# 1198                      Développeur(se) de blockchain
# 1219                              Expert en aquaculture
# 1355  Chauffeur VTC (voiture de transport avec chauf...
# 1565                    Ingénieur chimiste en industrie
# 1639  Technicien polyvalent en mécanique et travail ...
# 1648        Créateur de contenu sur les réseaux sociaux
# 1649        Créateur de contenu sur les réseaux sociaux
# 1772                      Livraison de repas à domicile
# 1773                      Livraison de repas à domicile
# 1778                                      Infographiste
# 1840  Chauffeur VTC (voiture de transport avec chauf...
# 1944                            Représentant commercial
# 1952                                      Monteur vidéo
# 2051                                Analyste de données
# 2288              Conseiller en nutrition et diététique
# 2736  Gestionnaire de réseaux sociaux pour des entre...
# 2806  Chargé(e) de la logistique d'une entreprise de...
# 2981                               Marketeur e-commerce
# 3068  Chauffeur VTC (voiture de transport avec chauf...
# 3123                      Développeur(se) de blockchain
# 3267                  Assistant en gestion du personnel
# 3351                       Conseiller en investissement
# 3380       Formateur et conseiller dans le domaine QHSE
#
#                                     matched_activity_ar  matched_code
# 44                       معلق الصوت الخلفي (voice-over)       10432.0
# 100                                صانع النماذج الجبسية       62505.0
# 156                                صانع النماذج الجبسية       62505.0
# 160    مسير وسائل التواصل الاجتماعي لشركات عبر الإنترنت       40107.0
# 198                            محلل التجارة الإلكترونية       21413.0
# 201                                          مصمم أحذية       10117.0
# 212                        سائق VTC (سيارة نقل مع سائق)       30904.0
# 215                     تقني تركيب في التيارات المنخفضة       63508.0
# 345                        سائق VTC (سيارة نقل مع سائق)       30904.0
# 370                                 خبير في ميدان الصيد       10732.0
# 572                                  مراسل وسائط متعددة       10430.0
# 609                                 مستشار في الاستثمار       10303.0
# 772                        سائق VTC (سيارة نقل مع سائق)       30904.0
# 1062                                  ممرض/ممرضة منزلية       40115.0
# 1184                     مكلف باللوجستيات في شركة توصيل       40101.0
# 1198                                    مطور Blockchain       21106.0
# 1219                                خبير في ميدان الصيد       10732.0
# 1355                       سائق VTC (سيارة نقل مع سائق)       30904.0
# 1565                           مهندس كيميائي في الصناعة       60503.0
# 1639                     تقني متعدد المهام في الميكانيك       61502.0
# 1648             صانع محتوى على وسائل التواصل الاجتماعي       20709.0
# 1649             صانع محتوى على وسائل التواصل الاجتماعي       20709.0
# 1772                           توصيل الوجبات إلى المنزل       40202.0
# 1773                           توصيل الوجبات إلى المنزل       40202.0
# 1778                                    مصمم انفوجرافيك       20703.0
# 1840                       سائق VTC (سيارة نقل مع سائق)       30904.0
# 1944                                       مندوب مبيعات       10306.0
# 1952                                       مركب الفيديو       71808.0
# 2051                                        محلل بيانات       20901.0
# 2288                                 مستشار تغدية وحمية       10213.0
# 2736   مسير وسائل التواصل الاجتماعي لشركات عبر الإنترنت       40107.0
# 2806                     مكلف باللوجستيات في شركة توصيل       40101.0
# 2981                           مسوق التجارة الالكترونية       21412.0
# 3068                       سائق VTC (سيارة نقل مع سائق)       30904.0
# 3123                                    مطور Blockchain       21106.0
# 3267                          مساعد في تسيير المستخدمين       70101.0
# 3351                                مستشار في الاستثمار       10303.0
# 3380  مكون ومستشار في مجال الجودة والنظافة والسلامة ...       10420.0
# Matched activities saved to: /content/drive/My Drive/hackathon1/matched_activities_only.xlsx
# Unmatched activities saved to: /content/drive/My Drive/hackathon1/not_matched_activities.xlsx

# %% [markdown]
# ## commercial use

# %%
import pandas as pd
from sentence_transformers import SentenceTransformer, util

# Load a multilingual model for embeddings
model = SentenceTransformer("Alibaba-NLP/gte-multilingual-base", trust_remote_code=True)

# Lists of traditional commercial activities (to exclude)
traditional_commercial_activities = [
    "restaurant", "vente", "achat", "café", "fast food", "boucherie", "poissonnerie", "téléphone",
    "bijouterie", "magasin", "boutique", "fournisseur", "détaillant", "grossiste", "revendeur",
    "importateur", "exportateur", "franchise", "vendeur", "commerçant", "négoce", "dépôt vente",
    "magasin alimentaire", "produits alimentaires", "produits de consommation", "liquidation",
    "bazar", "marché", "vente de voitures", "agents commerciaux", "services de livraison",
    "construction", "matériel de construction", "équipement industriel", "téléphonie mobile", "réparation",
    "location", "distribution", "importation", "commerce de détail", "distributeur", "commerçant de proximité",
    "agricole", "produits agricoles", "alimentation générale", "commerçant ambulant", "transports",
    "مطعم", "بيع", "شراء", "مقهى", "وجبات سريعة", "جزارة", "سمك", "هاتف", "مجوهرات", "متجر", "دكان",
    "مورد", "تاجر تجزئة", "تاجر جملة", "بائع", "مستورد", "مُصدر", "امتياز", "تجارة", "بيع بالتجزئة",
    "منتجات غذائية", "منتجات استهلاكية", "تصفية", "بازار", "سوق", "بيع السيارات", "وكلاء تجاريين",
    "خدمات التوصيل", "إنشاء", "معدات البناء", "تجهيزات صناعية", "هواتف محمولة", "صيانة", "إيجار",
    "توزيع", "استيراد", "تجارة التجزئة", "موزع", "تاجر محلي", "زراعي", "منتجات زراعية", "تجارة عامة",
    "تاجر متجول", "نقل"
]

# Allowed e-commerce & intermediary activities (to keep)
ecommerce_intermediary_activities = [
    "e-commerce", "plateforme de vente", "e-shop", "site marchand", "marketplace", "dropshipping",
    "affiliation", "vente en ligne", "webshop", "commerce virtuel", "commerce digital", "fournisseur e-commerce",
    "commerce électronique", "start-up", "entrepreneur digital", "services de paiement", "agent commercial",
    "courtier", "publicité en ligne", "consultant", "services en ligne", "freelance", "plateforme de freelancing",
    "commercialisation", "digital marketing", "plateforme B2B", "réseau de distribution",
    "تجارة إلكترونية", "منصة بيع", "متجر إلكتروني", "موقع تجاري", "سوق إلكتروني", "دروبشيبينغ",
    "تسويق بالعمولة", "متجر على الإنترنت", "تجارة افتراضية", "تجارة رقمية", "مورد تجارة إلكترونية",
    "شركة ناشئة", "ريادي رقمي", "خدمات الدفع", "وكيل تجاري", "سمسار", "إعلانات عبر الإنترنت",
    "مستشار", "خدمات عبر الإنترنت", "مستقل", "منصة عمل مستقل", "تسويق", "تسويق رقمي", "إدارة الحملات",
    "منصة إعلانات", "تسويق بالعمولة", "وسيط", "وكيل مبيعات", "حلول رقمية", "تخزين سحابي", "دعم العملاء",
    "إعلانات رقمية", "وسائل التواصل الاجتماعي", "منصة بي تو بي", "شبكة توزيع"
]

# Encode reference lists
embeddings_commercial = model.encode(traditional_commercial_activities, convert_to_tensor=True)
embeddings_ecommerce = model.encode(ecommerce_intermediary_activities, convert_to_tensor=True)

# Function to determine if an activity is traditional commercial
def classify_activity(activity_text):
    if pd.isna(activity_text):
        return False

    activity_embedding = model.encode(activity_text, convert_to_tensor=True)

    # Compute similarity scores
    similarity_commercial = util.cos_sim(activity_embedding, embeddings_commercial).max().item()
    similarity_ecommerce = util.cos_sim(activity_embedding, embeddings_ecommerce).max().item()

    # Threshold-based filtering
    if similarity_commercial > 0.7 and similarity_commercial > similarity_ecommerce:
        return True  # Exclude (Traditional Commercial)

    return False  # Keep (E-commerce / Valid Activity)

# Apply filtering
df_not_matched['is_traditional_commercial'] = df_not_matched['combined_text'].apply(classify_activity)

# Separate valid and removed activities
df_valid_activities = df_not_matched[df_not_matched['is_traditional_commercial'] == False].drop(columns=['is_traditional_commercial'])
df_removed_activities = df_not_matched[df_not_matched['is_traditional_commercial'] == True].drop(columns=['is_traditional_commercial'])

# Save filtered datasets
valid_activities_file = "/content/drive/My Drive/hackathon1/final_filtered_non_commercial.xlsx"
removed_activities_file = "/content/drive/My Drive/hackathon1/removed_commercial_activities.xlsx"

df_valid_activities.to_excel(valid_activities_file, index=False)
df_removed_activities.to_excel(removed_activities_file, index=False)

print(f"✅ Final filtered non-commercial & e-commerce activities saved to: {valid_activities_file}")
print(f"❌ Removed traditional commercial activities saved to: {removed_activities_file}")
# Out:
# Some weights of the model checkpoint at Alibaba-NLP/gte-multilingual-base were not used when initializing NewModel: {'classifier.weight', 'classifier.bias'}
# - This IS expected if you are initializing NewModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing NewModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# <ipython-input-23-059ceebd71ee>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_not_matched['is_traditional_commercial'] = df_not_matched['combined_text'].apply(classify_activity)
# ✅ Final filtered non-commercial & e-commerce activities saved to: /content/drive/My Drive/hackathon1/final_filtered_non_commercial.xlsx
# ❌ Removed traditional commercial activities saved to: /content/drive/My Drive/hackathon1/removed_commercial_activities.xlsx

# %% [markdown]
# # same optimize but just with activity not combiend with description

# %%
import pandas as pd
import re
import numpy as np
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
from unidecode import unidecode

# Load the multilingual Alibaba model
model = SentenceTransformer("Alibaba-NLP/gte-multilingual-base", trust_remote_code=True)

# Function to normalize Arabic text
def normalize_arabic(text):
    text = re.sub(r'[\u064B-\u065F]', '', text)  # Remove Arabic diacritics
    text = text.replace("أ", "ا").replace("إ", "ا").replace("آ", "ا")  # Normalize Alef variations
    text = text.replace("ة", "ه")  # Normalize Ta Marbuta
    text = text.replace("ى", "ي")  # Normalize Alef Maksura
    text = re.sub(r'[^\w\s]', '', text)  # Remove punctuation
    text = re.sub(r'\s+', ' ', text).strip()  # Remove extra spaces
    return text

# Function to normalize text (both Arabic & French)
def normalize_text(text):
    if not isinstance(text, str) or text.strip() == "":
        return ""
    text = text.lower().strip()
    if any("\u0600" <= c <= "\u06FF" for c in text):  # Check if Arabic characters exist
        text = normalize_arabic(text)
    else:
        text = unidecode(text)  # Use Unidecode for French
    text = re.sub(r'\d+', '', text)  # Remove digits
    return text


# Apply text normalization
df_mixed['processed_text'] = df_mixed['activity'].apply(normalize_text)

# Generate embeddings for all processed text
df_mixed['embeddings'] = df_mixed['processed_text'].astype(str).apply(lambda x: model.encode(x) if x.strip() else np.zeros(model.get_sentence_embedding_dimension()))

# Load official activity list
df_activities = pd.read_excel('/content/drive/My Drive/hackathon1/activities-hackathon/activity_list.xlsx')

# Normalize official activity names
df_activities['processed_activity'] = df_activities['name_activity'].apply(normalize_text)
df_activities['processed_activity_ar'] = df_activities['ar_name_activity'].apply(normalize_text)

# Generate embeddings for official activities
df_activities['activity_embedding'] = df_activities['processed_activity'].astype(str).apply(
    lambda x: model.encode(x) if x.strip() else np.zeros(model.get_sentence_embedding_dimension())
)
df_activities['activity_embedding_ar'] = df_activities['processed_activity_ar'].astype(str).apply(
    lambda x: model.encode(x) if x.strip() else np.zeros(model.get_sentence_embedding_dimension())
)

# 🚀 Convert embeddings to NumPy arrays for faster similarity search
activity_embeddings_fr = np.stack(df_activities['activity_embedding'].values)
activity_embeddings_ar = np.stack(df_activities['activity_embedding_ar'].values)

# Step 7: Optimized Matching Function
def find_best_match(row):
    # Compute similarity in bulk
    similarities_fr = cosine_similarity([row['embeddings']], activity_embeddings_fr)[0]
    similarities_ar = cosine_similarity([row['embeddings']], activity_embeddings_ar)[0]

    # Combine all similarities
    all_similarities = np.concatenate((similarities_fr, similarities_ar))

    # Get best match
    best_idx = np.argmax(all_similarities)
    best_similarity = all_similarities[best_idx]

    # Debugging output
    print(f"Best index: {best_idx}, Best similarity: {best_similarity}")

    if best_similarity >= 0.65 and best_idx < len(df_activities):
        best_match = df_activities.iloc[best_idx]
        return best_match['name_activity'], best_match['ar_name_activity'], best_match['code_activity']

    # Ensure we return a tuple of three elements
    return None, None, None

# Check if df_mixed and df_activities are not empty
if not df_mixed.empty and not df_activities.empty:
    # Apply the optimized matching function
    results = df_mixed.apply(find_best_match, axis=1)

    # Ensure results is a DataFrame
    df_results = pd.DataFrame(results.tolist(), columns=['matched_activity', 'matched_activity_ar', 'matched_code'])

    # Assign the results back to df_mixed
    df_mixed[['matched_activity', 'matched_activity_ar', 'matched_code']] = df_results

    # Save results
    df_mixed.to_excel('/content/drive/My Drive/hackathon1/matched_activities.xlsx', index=False)
    print("Matching process completed and saved to Excel.")

    # Filter rows where a match was found
    df_matched = df_mixed[df_mixed['matched_activity'].notna() & df_mixed['matched_code'].notna()]

    # Print matched rows
    print(df_matched[['activity', 'matched_activity', 'matched_activity_ar', 'matched_code']])

    # Save matched rows to a separate file
    matched_file_path = "/content/drive/My Drive/hackathon1/matched_activities_only.xlsx"
    df_matched.to_excel(matched_file_path, index=False)
    print(f"Matched activities saved to: {matched_file_path}")

    # Filter rows where NO match was found
    df_not_matched = df_mixed[df_mixed['matched_activity'].isna() | df_mixed['matched_code'].isna()]

    # Save unmatched rows to a separate file
    not_matched_file_path = "/content/drive/My Drive/hackathon1/not_matched_activities.xlsx"
    df_not_matched.to_excel(not_matched_file_path, index=False)
    print(f"Unmatched activities saved to: {not_matched_file_path}")
else:
    print("No data to process. Please check the input DataFrames.")
# Out:
# Some weights of the model checkpoint at Alibaba-NLP/gte-multilingual-base were not used when initializing NewModel: {'classifier.weight', 'classifier.bias'}
# - This IS expected if you are initializing NewModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing NewModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Best index: 2737, Best similarity: 0.7876622764111374
# Best index: 1633, Best similarity: 0.6239002080027085
# Best index: 1443, Best similarity: 0.6860524415969849
# Best index: 1427, Best similarity: 0.9999998807907104
# Best index: 2016, Best similarity: 0.7490373053329216
# Best index: 1400, Best similarity: 0.6958309412002563
# Best index: 1443, Best similarity: 0.9755682349205017
# Best index: 1764, Best similarity: 0.6860995067087932
# Best index: 920, Best similarity: 0.810370922088623
# Best index: 2879, Best similarity: 0.6806698013991368
# Best index: 1678, Best similarity: 0.7453273553012101
# Best index: 1857, Best similarity: 1.0000000000000009
# Best index: 1474, Best similarity: 0.7737803280592315
# Best index: 541, Best similarity: 0.7451014518737793
# Best index: 2372, Best similarity: 0.7059503140099703
# Best index: 1641, Best similarity: 0.7413548577344127
# Best index: 263, Best similarity: 0.6754361391067505
# Best index: 2893, Best similarity: 0.7714579668549555
# Best index: 1171, Best similarity: 0.8135275840759277
# Best index: 2843, Best similarity: 0.92134677824622
# Best index: 1650, Best similarity: 0.7437148682217869
# Best index: 705, Best similarity: 0.6511997580528259
# Best index: 1403, Best similarity: 0.8132147789001465
# Best index: 896, Best similarity: 0.6825642585754395
# Best index: 1678, Best similarity: 0.672920648015478
# Best index: 1972, Best similarity: 0.819484493919484
# Best index: 2304, Best similarity: 0.8375294726884035
# Best index: 1271, Best similarity: 0.6875673532485962
# Best index: 1957, Best similarity: 0.7031786767547156
# Best index: 2672, Best similarity: 0.6716654349584403
# Best index: 705, Best similarity: 0.6252428889274597
# Best index: 2823, Best similarity: 0.652873332069308
# Best index: 1455, Best similarity: 0.8073744773864746
# Best index: 730, Best similarity: 0.6705359220504761
# Best index: 541, Best similarity: 0.7705243825912476
# Best index: 1780, Best similarity: 0.6646045737818433
# Best index: 1492, Best similarity: 0.8133287550555857
# Best index: 118, Best similarity: 0.6838418245315552
# Best index: 2838, Best similarity: 0.7866552458050347
# Best index: 2460, Best similarity: 0.7923462800860717
# Best index: 1509, Best similarity: 0.7183825202965106
# Best index: 679, Best similarity: 0.7077785134315491
# Best index: 920, Best similarity: 0.810370922088623
# Best index: 2016, Best similarity: 0.7394066105561474
# Best index: 1365, Best similarity: 0.9999998807907104
# Best index: 1156, Best similarity: 0.787379801273346
# Best index: 2909, Best similarity: 0.9839725446775258
# Best index: 1337, Best similarity: 0.7063372135162354
# Best index: 781, Best similarity: 0.7415204048156738
# Best index: 897, Best similarity: 0.8063334226608276
# Best index: 1569, Best similarity: 0.7485875664986352
# Best index: 204, Best similarity: 0.7800757884979248
# Best index: 828, Best similarity: 0.8142117261886597
# Best index: 1875, Best similarity: 0.7847634002337988
# Best index: 920, Best similarity: 0.9999998807907104
# Best index: 1957, Best similarity: 0.7648281264849783
# Best index: 1617, Best similarity: 0.7536132380963908
# Best index: 967, Best similarity: 0.6415266990661621
# Best index: 524, Best similarity: 0.6666279435157776
# Best index: 2433, Best similarity: 0.8034926269398076
# Best index: 2586, Best similarity: 0.8482158469421535
# Best index: 348, Best similarity: 0.9072092771530151
# Best index: 1213, Best similarity: 1.000000238418579
# Best index: 2661, Best similarity: 0.6869407658011598
# Best index: 1631, Best similarity: 0.8102673586253252
# Best index: 1406, Best similarity: 0.7667911052703857
# Best index: 1857, Best similarity: 1.0000000000000009
# Best index: 1931, Best similarity: 0.7847008790165374
# Best index: 2894, Best similarity: 0.9225649184453945
# Best index: 1847, Best similarity: 0.7220409243268612
# Best index: 541, Best similarity: 0.6688631772994995
# Best index: 1492, Best similarity: 0.7419595820327196
# Best index: 919, Best similarity: 0.8175774812698364
# Best index: 2855, Best similarity: 0.6914857588401794
# Best index: 1617, Best similarity: 0.7445037964873865
# Best index: 853, Best similarity: 0.8166584968566895
# Best index: 2161, Best similarity: 0.7761363540623092
# Best index: 1358, Best similarity: 0.8563868999481201
# Best index: 2689, Best similarity: 0.7708265982104665
# Best index: 2672, Best similarity: 0.6460771264870597
# Best index: 1215, Best similarity: 0.713936448097229
# Best index: 491, Best similarity: 0.9325534105300903
# Best index: 2360, Best similarity: 0.9529008024537478
# Best index: 2041, Best similarity: 0.6973699059925571
# Best index: 1400, Best similarity: 0.8249211311340332
# Best index: 2835, Best similarity: 0.6339891818811907
# Best index: 2299, Best similarity: 0.7066771536965568
# Best index: 2062, Best similarity: 0.7621407577805699
# Best index: 1641, Best similarity: 0.8251997191103339
# Best index: 2354, Best similarity: 0.717648691749264
# Best index: 1564, Best similarity: 0.6772663792150638
# Best index: 2326, Best similarity: 0.8668426994934871
# Best index: 308, Best similarity: 0.799067497253418
# Best index: 554, Best similarity: 0.7439926862716675
# Best index: 1407, Best similarity: 0.7245567440986633
# Best index: 2919, Best similarity: 0.8132915121629332
# Best index: 1988, Best similarity: 0.6926996819255864
# Best index: 919, Best similarity: 0.8175774812698364
# Best index: 1381, Best similarity: 0.8125346899032593
# Best index: 1569, Best similarity: 0.6938514669525628
# Best index: 552, Best similarity: 1.0
# Best index: 1569, Best similarity: 0.7336797532922981
# Best index: 1407, Best similarity: 0.7245567440986633
# Best index: 2081, Best similarity: 0.614917728100091
# Best index: 1497, Best similarity: 0.7484799693070113
# Best index: 2891, Best similarity: 0.6892710222592476
# Best index: 2913, Best similarity: 0.627311221666
# Best index: 1569, Best similarity: 0.7485875664986352
# Best index: 1668, Best similarity: 0.6897949145765508
# Best index: 559, Best similarity: 0.6985852718353271
# Best index: 1381, Best similarity: 0.655658483505249
# Best index: 2594, Best similarity: 0.7543803225160597
# Best index: 622, Best similarity: 0.6009643077850342
# Best index: 301, Best similarity: 0.8523125648498535
# Best index: 2919, Best similarity: 0.8252728156159903
# Best index: 2362, Best similarity: 0.6807005793977572
# Best index: 2893, Best similarity: 0.9769210077580575
# Best index: 6, Best similarity: 0.6853100061416626
# Best index: 2534, Best similarity: 0.7042131117940043
# Best index: 853, Best similarity: 0.8166584968566895
# Best index: 1403, Best similarity: 0.7235566973686218
# Best index: 2506, Best similarity: 0.8817461676120031
# Best index: 2038, Best similarity: 0.6518071966054125
# Best index: 909, Best similarity: 0.6699872016906738
# Best index: 1273, Best similarity: 0.7955784797668457
# Best index: 1183, Best similarity: 0.7414306402206421
# Best index: 2873, Best similarity: 0.8228318762441736
# Best index: 213, Best similarity: 0.6416815519332886
# Best index: 1585, Best similarity: 0.6529316725561432
# Best index: 969, Best similarity: 0.7759698629379272
# Best index: 213, Best similarity: 0.6805453896522522
# Best index: 920, Best similarity: 0.650719165802002
# Best index: 1056, Best similarity: 0.731541633605957
# Best index: 1617, Best similarity: 0.7164229659036392
# Best index: 2858, Best similarity: 0.6548416559284138
# Best index: 909, Best similarity: 0.6891361474990845
# Best index: 1381, Best similarity: 0.6778221130371094
# Best index: 890, Best similarity: 0.8661521077156067
# Best index: 996, Best similarity: 0.7185119390487671
# Best index: 1385, Best similarity: 0.7113462090492249
# Best index: 2349, Best similarity: 0.7721308881677054
# Best index: 1959, Best similarity: 0.7080065693210471
# Best index: 1473, Best similarity: 0.7401413249506563
# Best index: 1338, Best similarity: 0.7776023745536804
# Best index: 2874, Best similarity: 0.8176265503179326
# Best index: 2358, Best similarity: 0.6537338976214204
# Best index: 2920, Best similarity: 0.7266644940325936
# Best index: 1569, Best similarity: 0.7485875664986352
# Best index: 2084, Best similarity: 0.711459810843829
# Best index: 1425, Best similarity: 0.8711182475090027
# Best index: 890, Best similarity: 0.786765456199646
# Best index: 1569, Best similarity: 0.7485875664986352
# Best index: 776, Best similarity: 0.796271026134491
# Best index: 2907, Best similarity: 0.8294284284814559
# Best index: 1833, Best similarity: 1.0000000000000002
# Best index: 1946, Best similarity: 0.7023994233829975
# Best index: 552, Best similarity: 1.0
# Best index: 2827, Best similarity: 0.7560450736916835
# Best index: 1792, Best similarity: 0.7853387503238074
# Best index: 1078, Best similarity: 0.9694383144378662
# Best index: 911, Best similarity: 0.8561943769454956
# Best index: 1957, Best similarity: 0.7109492555586877
# Best index: 2846, Best similarity: 0.6966921177213032
# Best index: 2236, Best similarity: 0.717272525865499
# Best index: 984, Best similarity: 0.6819629073143005
# Best index: 121, Best similarity: 0.6017300486564636
# Best index: 835, Best similarity: 0.706426739692688
# Best index: 895, Best similarity: 1.0
# Best index: 1944, Best similarity: 0.6481732434963485
# Best index: 920, Best similarity: 0.9374883770942688
# Best index: 222, Best similarity: 0.6816340684890747
# Best index: 886, Best similarity: 0.6472545862197876
# Best index: 2382, Best similarity: 0.9999999999999998
# Best index: 1543, Best similarity: 0.7635709160670843
# Best index: 2305, Best similarity: 1.000000000000001
# Best index: 153, Best similarity: 0.6194920539855957
# Best index: 1449, Best similarity: 0.7783259749412537
# Best index: 8, Best similarity: 0.720277726650238
# Best index: 305, Best similarity: 0.6518797278404236
# Best index: 35, Best similarity: 0.6851560473442078
# Best index: 2879, Best similarity: 0.7239131502580962
# Best index: 64, Best similarity: 0.6729960441589355
# Best index: 2020, Best similarity: 0.7434347295709434
# Best index: 2878, Best similarity: 0.6907994888286233
# Best index: 1380, Best similarity: 0.8016414642333984
# Best index: 1957, Best similarity: 0.769008878354112
# Best index: 205, Best similarity: 0.6680662631988525
# Best index: 1808, Best similarity: 0.674812336425218
# Best index: 2020, Best similarity: 0.7331008063891529
# Best index: 2890, Best similarity: 0.7104293613720185
# Best index: 2892, Best similarity: 0.7581650476683546
# Best index: 1523, Best similarity: 0.7070102204379553
# Best index: 1217, Best similarity: 0.710342288017273
# Best index: 2356, Best similarity: 0.9256049473531898
# Best index: 2849, Best similarity: 0.716262317037256
# Best index: 1288, Best similarity: 0.7236394882202148
# Best index: 1381, Best similarity: 0.7187561988830566
# Best index: 1957, Best similarity: 0.7768027140994642
# Best index: 1078, Best similarity: 1.0
# Best index: 2628, Best similarity: 0.7476133240291751
# Best index: 1683, Best similarity: 0.6807150530998302
# Best index: 1447, Best similarity: 1.0
# Best index: 17, Best similarity: 0.7754936218261719
# Best index: 1115, Best similarity: 0.6041780710220337
# Best index: 2907, Best similarity: 0.7576562973805574
# Best index: 917, Best similarity: 0.7180429697036743
# Best index: 1492, Best similarity: 0.6604287034189014
# Best index: 2369, Best similarity: 0.7935063470847903
# Best index: 2595, Best similarity: 0.7591705632238241
# Best index: 2672, Best similarity: 0.7269403891149409
# Best index: 2672, Best similarity: 0.6716654349584403
# Best index: 2907, Best similarity: 0.612914333792647
# Best index: 920, Best similarity: 0.9920790195465088
# Best index: 919, Best similarity: 0.8175774812698364
# Best index: 2806, Best similarity: 0.6550900812874856
# Best index: 380, Best similarity: 0.9859722256660461
# Best index: 2838, Best similarity: 0.6892811188077346
# Best index: 2357, Best similarity: 0.8844833115761548
# Best index: 1968, Best similarity: 0.6718359488871881
# Best index: 2672, Best similarity: 0.6801828478522915
# Best index: 2016, Best similarity: 1.0000000000000009
# Best index: 2893, Best similarity: 0.6565261804461999
# Best index: 2157, Best similarity: 0.7457563411319835
# Best index: 2892, Best similarity: 0.7308568576661726
# Best index: 45, Best similarity: 0.6520302295684814
# Best index: 1257, Best similarity: 0.7238833904266357
# Best index: 1234, Best similarity: 0.6865196824073792
# Best index: 2735, Best similarity: 0.7372905257087966
# Best index: 1440, Best similarity: 0.780134916305542
# Best index: 917, Best similarity: 0.7180429697036743
# Best index: 484, Best similarity: 0.6698867082595825
# Best index: 2346, Best similarity: 0.6892303560494932
# Best index: 2845, Best similarity: 0.65669787027681
# Best index: 958, Best similarity: 0.8708608150482178
# Best index: 2737, Best similarity: 0.7766499703939442
# Best index: 2907, Best similarity: 0.6547476892208499
# Best index: 2542, Best similarity: 0.9192109185449358
# Best index: 1457, Best similarity: 0.7500628232955933
# Best index: 1171, Best similarity: 0.8025720119476318
# Best index: 1912, Best similarity: 0.7812701096471171
# Best index: 920, Best similarity: 0.7947817444801331
# Best index: 770, Best similarity: 0.7407315969467163
# Best index: 348, Best similarity: 0.9072092771530151
# Best index: 1780, Best similarity: 0.8287615201844909
# Best index: 890, Best similarity: 0.9586352109909058
# Best index: 1812, Best similarity: 0.8023123958654881
# Best index: 1076, Best similarity: 0.7926021814346313
# Best index: 405, Best similarity: 0.8292008638381958
# Best index: 2023, Best similarity: 0.6732624454133618
# Best index: 124, Best similarity: 0.6623444557189941
# Best index: 474, Best similarity: 0.7751713395118713
# Best index: 1441, Best similarity: 1.000000238418579
# Best index: 608, Best similarity: 0.784917414188385
# Best index: 1183, Best similarity: 0.6722494959831238
# Best index: 2884, Best similarity: 0.8178595937048843
# Best index: 2560, Best similarity: 0.8312819108215064
# Best index: 1481, Best similarity: 0.7904823944309658
# Best index: 1817, Best similarity: 0.7740732748348382
# Best index: 1569, Best similarity: 0.7485875664986352
# Best index: 1416, Best similarity: 0.7060489654541016
# Best index: 2848, Best similarity: 0.7150404043439321
# Best index: 2028, Best similarity: 0.6792769497348358
# Best index: 735, Best similarity: 0.6761212348937988
# Best index: 2020, Best similarity: 0.7990258828961323
# Best index: 1438, Best similarity: 0.6603118181228638
# Best index: 1451, Best similarity: 0.6572397947311401
# Best index: 917, Best similarity: 0.7638150453567505
# Best index: 1792, Best similarity: 0.7660534401329742
# Best index: 2920, Best similarity: 0.7266644940325936
# Best index: 1671, Best similarity: 0.6517079133614311
# Best index: 2293, Best similarity: 0.6970954633542996
# Best index: 792, Best similarity: 0.8481431007385254
# Best index: 890, Best similarity: 0.8661521077156067
# Best index: 1492, Best similarity: 0.8141564252449309
# Best index: 422, Best similarity: 0.6739195585250854
# Best index: 386, Best similarity: 0.8668171167373657
# Best index: 2893, Best similarity: 0.7737446773706995
# Best index: 792, Best similarity: 0.9222159385681152
# Best index: 894, Best similarity: 0.7131085395812988
# Best index: 1724, Best similarity: 0.7528211630635286
# Best index: 554, Best similarity: 0.7439926862716675
# Best index: 484, Best similarity: 0.6935282945632935
# Best index: 2864, Best similarity: 0.7325085311235463
# Best index: 1957, Best similarity: 0.7259169596851197
# Best index: 2542, Best similarity: 0.8564662133322867
# Best index: 1424, Best similarity: 0.7543538808822632
# Best index: 2920, Best similarity: 0.7813625538720003
# Best index: 1569, Best similarity: 0.7485875664986352
# Best index: 2354, Best similarity: 0.7394503217223238
# Best index: 1486, Best similarity: 0.7107476214756259
# Best index: 2351, Best similarity: 0.6681645490925007
# Best index: 1522, Best similarity: 0.7008750908164338
# Best index: 1354, Best similarity: 0.9074803590774536
# Best index: 54, Best similarity: 0.7328513860702515
# Best index: 1381, Best similarity: 0.7421733140945435
# Best index: 621, Best similarity: 0.6721956729888916
# Best index: 1374, Best similarity: 0.7943189740180969
# Best index: 2528, Best similarity: 0.7486952234698505
# Best index: 2905, Best similarity: 0.9507246258526152
# Best index: 63, Best similarity: 0.7416195273399353
# Best index: 640, Best similarity: 0.6961946487426758
# Best index: 1425, Best similarity: 0.7420442700386047
# Best index: 318, Best similarity: 0.7530090808868408
# Best index: 2044, Best similarity: 0.6740162406501184
# Best index: 1718, Best similarity: 0.6075960036544448
# Best index: 263, Best similarity: 0.7093797922134399
# Best index: 1561, Best similarity: 0.7386674603879182
# Best index: 538, Best similarity: 0.7022883892059326
# Best index: 1424, Best similarity: 0.7543538808822632
# Best index: 1341, Best similarity: 0.7378592491149902
# Best index: 1569, Best similarity: 0.7485875664986352
# Best index: 1876, Best similarity: 0.841443763009809
# Best index: 2767, Best similarity: 0.771650571193663
# Best index: 0, Best similarity: 0.0
# Best index: 1327, Best similarity: 0.7594789266586304
# Best index: 2562, Best similarity: 0.7097317899689831
# Best index: 765, Best similarity: 0.8829290866851807
# Best index: 2817, Best similarity: 0.7427047695896771
# Best index: 2028, Best similarity: 0.6792769497348358
# Best index: 1367, Best similarity: 0.7479757070541382
# Best index: 2903, Best similarity: 0.7107451084725032
# Best index: 2243, Best similarity: 0.6654979302495746
# Best index: 554, Best similarity: 0.7439926862716675
# Best index: 2354, Best similarity: 0.7110964499411032
# Best index: 2542, Best similarity: 0.8830119047329716
# Best index: 2243, Best similarity: 0.646990394201462
# Best index: 2900, Best similarity: 0.6974947181175066
# Best index: 2893, Best similarity: 0.8135653683599662
# Best index: 2879, Best similarity: 0.6806698013991368
# Best index: 2864, Best similarity: 0.6975039581431196
# Best index: 2864, Best similarity: 0.6720118060516657
# Best index: 1271, Best similarity: 0.7232396006584167
# Best index: 1439, Best similarity: 0.7408161163330078
# Best index: 2542, Best similarity: 0.7604095885969797
# Best index: 1184, Best similarity: 0.7173439264297485
# Best index: 371, Best similarity: 0.6896487474441528
# Best index: 2839, Best similarity: 0.6992401210000248
# Best index: 2672, Best similarity: 0.6716654349584403
# Best index: 1612, Best similarity: 0.7701169873415707
# Best index: 2354, Best similarity: 0.7923048227733216
# Best index: 1393, Best similarity: 0.7175007462501526
# Best index: 1740, Best similarity: 0.9067116262033066
# Best index: 1058, Best similarity: 0.6701009273529053
# Best index: 1508, Best similarity: 0.7236703588083842
# Best index: 2880, Best similarity: 0.7648780577495059
# Best index: 920, Best similarity: 0.7947817444801331
# Best index: 2914, Best similarity: 0.7315861777911563
# Best index: 2552, Best similarity: 0.7560476736153683
# Best index: 608, Best similarity: 0.7372673749923706
# Best index: 1974, Best similarity: 0.7893497490605638
# Best index: 1693, Best similarity: 0.6082672841747547
# Best index: 1721, Best similarity: 0.8207825053433736
# Best index: 1374, Best similarity: 0.6737160682678223
# Best index: 2864, Best similarity: 0.6611880904777085
# Best index: 2600, Best similarity: 0.8356056542751971
# Best index: 1434, Best similarity: 0.8517653942108154
# Best index: 1443, Best similarity: 0.7948809862136841
# Best index: 2532, Best similarity: 0.659019228957191
# Best index: 2881, Best similarity: 0.8623718476363563
# Best index: 682, Best similarity: 0.7430567145347595
# Best index: 1068, Best similarity: 0.9462820291519165
# Best index: 761, Best similarity: 0.6633896231651306
# Best index: 1423, Best similarity: 0.6720611453056335
# Best index: 2857, Best similarity: 0.7933619242587566
# Best index: 682, Best similarity: 0.7764375805854797
# Best index: 2600, Best similarity: 0.725187174702921
# Best index: 916, Best similarity: 0.7258371114730835
# Best index: 1337, Best similarity: 0.6670647263526917
# Best index: 2672, Best similarity: 0.7485917398050765
# Best index: 2293, Best similarity: 0.6078534747660708
# Best index: 1301, Best similarity: 0.8658658862113953
# Best index: 1818, Best similarity: 0.726157212440812
# Best index: 2866, Best similarity: 0.6456015702030036
# Best index: 422, Best similarity: 0.7180138826370239
# Best index: 98, Best similarity: 0.7118891477584839
# Best index: 1164, Best similarity: 0.986352801322937
# Best index: 1492, Best similarity: 0.8141564252449309
# Best index: 1337, Best similarity: 0.6670647263526917
# Best index: 17, Best similarity: 0.7145621180534363
# Best index: 1364, Best similarity: 0.665695071220398
# Best index: 2675, Best similarity: 0.733435763027998
# Best index: 1455, Best similarity: 0.7793102264404297
# Best index: 2023, Best similarity: 0.6172661266221682
# Best index: 2021, Best similarity: 0.6343980553285122
# Best index: 2902, Best similarity: 0.716449987585158
# Best index: 2646, Best similarity: 0.9165745598027595
# Best index: 479, Best similarity: 0.6441856622695923
# Best index: 917, Best similarity: 0.9234827160835266
# Best index: 812, Best similarity: 0.6467849016189575
# Best index: 2855, Best similarity: 0.6816213154012079
# Best index: 2912, Best similarity: 0.7749930841862549
# Best index: 0, Best similarity: 0.0
# Best index: 1461, Best similarity: 0.7373533248901367
# Best index: 1969, Best similarity: 0.7690749344951474
# Best index: 2879, Best similarity: 0.6309842665872425
# Best index: 2746, Best similarity: 0.7603772798538744
# Best index: 64, Best similarity: 0.7205185294151306
# Best index: 459, Best similarity: 0.898499608039856
# Best index: 2600, Best similarity: 0.7924019963804849
# Best index: 2672, Best similarity: 0.6870305252074511
# Best index: 1944, Best similarity: 0.6702916766952427
# Best index: 2916, Best similarity: 0.877851255470945
# Best index: 1295, Best similarity: 0.7333918809890747
# Best index: 2827, Best similarity: 0.7094443663543656
# Best index: 151, Best similarity: 0.7749104499816895
# Best index: 891, Best similarity: 0.6557343006134033
# Best index: 1305, Best similarity: 0.645639181137085
# Best index: 1443, Best similarity: 0.7822808623313904
# Best index: 1068, Best similarity: 0.7321617603302002
# Best index: 2846, Best similarity: 0.6180800694375823
# Best index: 2864, Best similarity: 0.67759767939218
# Best index: 2672, Best similarity: 0.6870305252074511
# Best index: 1383, Best similarity: 0.7115758657455444
# Best index: 0, Best similarity: 0.0
# Best index: 346, Best similarity: 1.0000001192092896
# Best index: 2827, Best similarity: 0.7254132382244691
# Best index: 2602, Best similarity: 0.7794480323796655
# Best index: 1076, Best similarity: 0.7926021814346313
# Best index: 2920, Best similarity: 0.7597754540292524
# Best index: 64, Best similarity: 0.7205185294151306
# Best index: 1170, Best similarity: 0.9516898393630981
# Best index: 894, Best similarity: 0.7826739549636841
# Best index: 894, Best similarity: 0.7397376298904419
# Best index: 1764, Best similarity: 0.7613830756879201
# Best index: 228, Best similarity: 0.8249763250350952
# Best index: 917, Best similarity: 0.7946246862411499
# Best index: 534, Best similarity: 0.73641037940979
# Best index: 1665, Best similarity: 0.6846028549397061
# Best index: 153, Best similarity: 0.6948592066764832
# Best index: 894, Best similarity: 0.9041719436645508
# Best index: 1813, Best similarity: 0.6683911735374134
# Best index: 2435, Best similarity: 0.704250103504626
# Best index: 54, Best similarity: 1.0000001192092896
# Best index: 2346, Best similarity: 0.7797158052038171
# Best index: 1076, Best similarity: 0.7926021814346313
# Best index: 608, Best similarity: 0.7179826498031616
# Best index: 1351, Best similarity: 0.7627186179161072
# Best index: 1381, Best similarity: 0.7521628141403198
# Best index: 2864, Best similarity: 0.7252952775764965
# Best index: 1425, Best similarity: 0.7420442700386047
# Best index: 2806, Best similarity: 0.6537186439162768
# Best index: 2835, Best similarity: 0.6704404476406847
# Best index: 1455, Best similarity: 0.8262790441513062
# Best index: 1164, Best similarity: 0.7877117991447449
# Best index: 2542, Best similarity: 0.7335947072348936
# Best index: 1932, Best similarity: 0.711694722278033
# Best index: 518, Best similarity: 0.6527101993560791
# Best index: 551, Best similarity: 0.6624707579612732
# Best index: 1435, Best similarity: 0.7107691764831543
# Best index: 2903, Best similarity: 0.715636089130463
# Best index: 2832, Best similarity: 0.7419555303844684
# Best index: 263, Best similarity: 0.7093797922134399
# Best index: 920, Best similarity: 0.9374883770942688
# Best index: 1769, Best similarity: 0.8283236149719048
# Best index: 1686, Best similarity: 0.619767200767524
# Best index: 2873, Best similarity: 0.7645876696745689
# Best index: 674, Best similarity: 0.7477015256881714
# Best index: 1391, Best similarity: 0.6968061327934265
# Best index: 781, Best similarity: 0.6733315587043762
# Best index: 492, Best similarity: 0.6910296678543091
# Best index: 2759, Best similarity: 0.8499842998681199
# Best index: 1492, Best similarity: 0.7425838849913478
# Best index: 2737, Best similarity: 0.7876622764111374
# Best index: 2737, Best similarity: 0.7876622764111374
# Best index: 1523, Best similarity: 0.6325757588276644
# Best index: 1678, Best similarity: 0.6567119085700561
# Best index: 362, Best similarity: 0.7956652641296387
# Best index: 2584, Best similarity: 0.6931432854385478
# Best index: 1957, Best similarity: 0.769008878354112
# Best index: 2893, Best similarity: 0.6314084439650212
# Best index: 2864, Best similarity: 0.8538921459340502
# Best index: 149, Best similarity: 0.7314664125442505
# Best index: 2872, Best similarity: 0.6220397222954823
# Best index: 16, Best similarity: 0.7479057908058167
# Best index: 1351, Best similarity: 0.7493678331375122
# Best index: 2353, Best similarity: 0.7252420647667397
# Best index: 1907, Best similarity: 0.7749928290990971
# Best index: 920, Best similarity: 0.9374883770942688
# Best index: 1283, Best similarity: 0.6540813446044922
# Best index: 2747, Best similarity: 0.6964492112929845
# Best index: 204, Best similarity: 0.7149983644485474
# Best index: 2894, Best similarity: 0.7123723063165952
# Best index: 2245, Best similarity: 0.7576227685800829
# Best index: 2864, Best similarity: 0.7029779442010239
# Best index: 1411, Best similarity: 0.9982173442840576
# Best index: 198, Best similarity: 0.6743505001068115
# Best index: 1957, Best similarity: 0.769008878354112
# Best index: 1047, Best similarity: 0.9958981275558472
# Best index: 2907, Best similarity: 0.6524198435733151
# Best index: 1920, Best similarity: 0.8210284147761753
# Best index: 1356, Best similarity: 0.8889152407646179
# Best index: 1363, Best similarity: 0.764415979385376
# Best index: 1564, Best similarity: 0.6772663792150638
# Best index: 920, Best similarity: 0.7947817444801331
# Best index: 2893, Best similarity: 0.6314084439650212
# Best index: 2476, Best similarity: 0.685261054309252
# Best index: 1262, Best similarity: 0.7260217666625977
# Best index: 1407, Best similarity: 0.6598416566848755
# Best index: 1687, Best similarity: 0.7927691586498737
# Best index: 2560, Best similarity: 0.789439846169932
# Best index: 1319, Best similarity: 0.756345808506012
# Best index: 1427, Best similarity: 0.7053518295288086
# Best index: 2893, Best similarity: 0.6314084439650212
# Best index: 920, Best similarity: 0.7947817444801331
# Best index: 2476, Best similarity: 0.6608573494577838
# Best index: 2864, Best similarity: 0.6491555044316529
# Best index: 1866, Best similarity: 0.6086899395793959
# Best index: 277, Best similarity: 0.7342976331710815
# Best index: 2893, Best similarity: 0.9449831673222087
# Best index: 2555, Best similarity: 0.762912733259903
# Best index: 1492, Best similarity: 0.7690574167088421
# Best index: 2857, Best similarity: 0.7092131451935442
# Best index: 1078, Best similarity: 0.770494282245636
# Best index: 1687, Best similarity: 0.7206670302995186
# Best index: 248, Best similarity: 0.6698545217514038
# Best index: 1156, Best similarity: 0.6559561491012573
# Best index: 223, Best similarity: 0.7423744201660156
# Best index: 2893, Best similarity: 0.7286102428281639
# Best index: 920, Best similarity: 0.9374883770942688
# Best index: 2920, Best similarity: 0.7266644940325936
# Best index: 1523, Best similarity: 0.7345233790777943
# Best index: 367, Best similarity: 0.700933575630188
# Best index: 668, Best similarity: 0.6840536594390869
# Best index: 2542, Best similarity: 0.8947142423859359
# Best index: 2032, Best similarity: 0.7032352865473308
# Best index: 1384, Best similarity: 0.7761027812957764
# Best index: 1464, Best similarity: 1.0
# Best index: 1569, Best similarity: 0.7485875664986352
# Best index: 2014, Best similarity: 0.6574128699240833
# Best index: 2920, Best similarity: 0.7355169320402664
# Best index: 2759, Best similarity: 0.7016935658815319
# Best index: 885, Best similarity: 0.7922397255897522
# Best index: 2864, Best similarity: 0.6838865389768487
# Best index: 2357, Best similarity: 0.8724461769351999
# Best index: 54, Best similarity: 0.7696369290351868
# Best index: 1483, Best similarity: 0.7918089133734845
# Best index: 0, Best similarity: 0.0
# Best index: 1767, Best similarity: 0.7146665212597194
# Best index: 1434, Best similarity: 0.7109173536300659
# Best index: 2915, Best similarity: 0.7246794721459028
# Best index: 996, Best similarity: 0.7140375375747681
# Best index: 2326, Best similarity: 0.8479651895024528
# Best index: 0, Best similarity: 0.0
# Best index: 1810, Best similarity: 0.6793366351907721
# Best index: 0, Best similarity: 0.0
# Best index: 2379, Best similarity: 0.6519691918491914
# Best index: 1999, Best similarity: 0.5963263806122177
# Best index: 2818, Best similarity: 0.7653476776939796
# Best index: 1684, Best similarity: 0.8011079211049781
# Best index: 3, Best similarity: 0.9153697490692139
# Best index: 1768, Best similarity: 0.7082810786359965
# Best index: 1828, Best similarity: 0.692133980645328
# Best index: 2780, Best similarity: 0.7274615816845149
# Best index: 2780, Best similarity: 0.7274615816845149
# Best index: 1911, Best similarity: 0.8272773423123324
# Best index: 1483, Best similarity: 0.7792220093028345
# Best index: 168, Best similarity: 0.6923245191574097
# Best index: 2358, Best similarity: 0.7980102147051977
# Best index: 2864, Best similarity: 0.8920575886818689
# Best index: 59, Best similarity: 0.7171094417572021
# Best index: 896, Best similarity: 0.6606552600860596
# Best index: 1338, Best similarity: 0.6694207191467285
# Best index: 1991, Best similarity: 0.6696291779198378
# Best index: 902, Best similarity: 0.7605620622634888
# Best index: 0, Best similarity: 0.0
# Best index: 0, Best similarity: 0.0
# Best index: 1363, Best similarity: 0.6464557647705078
# Best index: 1914, Best similarity: 0.6227133629965536
# Best index: 608, Best similarity: 0.6799129247665405
# Best index: 1351, Best similarity: 0.7524839639663696
# Best index: 2858, Best similarity: 0.7220047001973333
# Best index: 2893, Best similarity: 0.8386535547598396
# Best index: 1367, Best similarity: 0.8833363056182861
# Best index: 2907, Best similarity: 0.6964392185968231
# Best index: 2245, Best similarity: 0.6969692276611852
# Best index: 1947, Best similarity: 0.8236139824015677
# Best index: 1449, Best similarity: 0.7473270893096924
# Best index: 1942, Best similarity: 0.8276062874971828
# Best index: 821, Best similarity: 0.693512499332428
# Best index: 920, Best similarity: 0.7947817444801331
# Best index: 920, Best similarity: 0.7947817444801331
# Best index: 98, Best similarity: 0.7675107717514038
# Best index: 2920, Best similarity: 0.7266644940325936
# Best index: 1383, Best similarity: 0.6942558884620667
# Best index: 1451, Best similarity: 0.7019388675689697
# Best index: 920, Best similarity: 0.7947817444801331
# Best index: 898, Best similarity: 0.6394963264465332
# Best index: 902, Best similarity: 0.8302687406539917
# Best index: 2625, Best similarity: 0.7401824933723258
# Best index: 1444, Best similarity: 0.7440543174743652
# Best index: 1136, Best similarity: 0.803204357624054
# Best index: 2305, Best similarity: 0.8162457202221126
# Best index: 2861, Best similarity: 0.8223354318579615
# Best index: 554, Best similarity: 0.8239197731018066
# Best index: 1617, Best similarity: 0.7870291665977363
# Best index: 2362, Best similarity: 0.7265897159307266
# Best index: 2247, Best similarity: 0.6787174782419149
# Best index: 2625, Best similarity: 0.7858366063742622
# Best index: 2818, Best similarity: 0.7594871909129537
# Best index: 1665, Best similarity: 0.700328542053762
# Best index: 1957, Best similarity: 0.7608392289546295
# Best index: 367, Best similarity: 0.6579517126083374
# Best index: 775, Best similarity: 0.7104039192199707
# Best index: 890, Best similarity: 0.7342013120651245
# Best index: 2838, Best similarity: 0.7926682990394944
# Best index: 2864, Best similarity: 0.6572757509746561
# Best index: 551, Best similarity: 0.6557495594024658
# Best index: 37, Best similarity: 0.6840183138847351
# Best index: 457, Best similarity: 0.6604955196380615
# Best index: 1403, Best similarity: 0.8921369314193726
# Best index: 2354, Best similarity: 0.6752340541660689
# Best index: 2835, Best similarity: 0.6050297806734224
# Best index: 2388, Best similarity: 0.8353007511693988
# Best index: 839, Best similarity: 0.6848093867301941
# Best index: 2020, Best similarity: 0.6946864261268167
# Best index: 2879, Best similarity: 0.6806698013991368
# Best index: 2676, Best similarity: 0.7596199121037084
# Best index: 2886, Best similarity: 0.6644671694804137
# Best index: 1438, Best similarity: 0.8264317512512207
# Best index: 1656, Best similarity: 0.6488760367369875
# Best index: 2384, Best similarity: 0.8792545203597435
# Best index: 0, Best similarity: 0.0
# Best index: 1400, Best similarity: 0.7556853294372559
# Best index: 2905, Best similarity: 0.6894048191244213
# Best index: 2823, Best similarity: 0.652873332069308
# Best index: 0, Best similarity: 0.0
# Best index: 1943, Best similarity: 0.7150602642769606
# Best index: 1870, Best similarity: 0.5858066563431421
# Best index: 2657, Best similarity: 0.6209265439902834
# Best index: 920, Best similarity: 0.7947817444801331
# Best index: 1948, Best similarity: 0.6800699276075985
# Best index: 917, Best similarity: 0.7452213764190674
# Best index: 2747, Best similarity: 0.6997225460682814
# Best index: 917, Best similarity: 0.7520625591278076
# Best index: 2902, Best similarity: 0.6402393290628523
# Best index: 2873, Best similarity: 0.7873968285448336
# Best index: 2838, Best similarity: 0.7377591119955006
# Best index: 1957, Best similarity: 0.6725632875892155
# Best index: 2767, Best similarity: 0.8148549751380796
# Best index: 2293, Best similarity: 0.7684760216669139
# Best index: 1629, Best similarity: 0.6924459220330821
# Best index: 2767, Best similarity: 0.8067471554991512
# Best index: 2916, Best similarity: 0.8649565060028553
# Best index: 1994, Best similarity: 0.5965483123664539
# Best index: 367, Best similarity: 0.7282434105873108
# Best index: 2810, Best similarity: 0.75944765764995
# Best index: 1503, Best similarity: 0.6903578359427498
# Best index: 916, Best similarity: 0.7626992464065552
# Best index: 1399, Best similarity: 0.8048526048660278
# Best index: 2672, Best similarity: 0.6870305252074511
# Best index: 1164, Best similarity: 0.6967467665672302
# Best index: 153, Best similarity: 0.7453174591064453
# Best index: 1988, Best similarity: 0.6491760221214777
# Best index: 1461, Best similarity: 0.8576119542121887
# Best index: 499, Best similarity: 0.760259747505188
# Best index: 1988, Best similarity: 0.7217414345293988
# Best index: 2356, Best similarity: 0.9322562014556421
# Best index: 902, Best similarity: 0.6579798460006714
# Best index: 1948, Best similarity: 0.6085702251333633
# Best index: 1416, Best similarity: 0.6803865432739258
# Best index: 1491, Best similarity: 0.6660638739069265
# Best index: 2453, Best similarity: 0.7359980283300582
# Best index: 1523, Best similarity: 0.6877690181164949
# Best index: 2880, Best similarity: 0.7135532219042242
# Best index: 2436, Best similarity: 0.8375380082065954
# Best index: 2864, Best similarity: 0.7029779442010239
# Best index: 2305, Best similarity: 0.8162457202221126
# Best index: 1455, Best similarity: 0.7749097347259521
# Best index: 820, Best similarity: 0.8072956204414368
# Best index: 1429, Best similarity: 0.8029979467391968
# Best index: 1641, Best similarity: 0.7225177478411969
# Best index: 2346, Best similarity: 0.7300419480447822
# Best index: 2893, Best similarity: 0.8535143848538359
# Best index: 1369, Best similarity: 0.745871901512146
# Best index: 559, Best similarity: 0.69272780418396
# Best index: 559, Best similarity: 0.69272780418396
# Best index: 1764, Best similarity: 0.6921800673431544
# Best index: 2303, Best similarity: 0.897194570230547
# Best index: 1379, Best similarity: 0.7409557104110718
# Best index: 2542, Best similarity: 0.896628264071178
# Best index: 761, Best similarity: 0.6484695672988892
# Best index: 2920, Best similarity: 0.7266644940325936
# Best index: 1389, Best similarity: 0.7495520114898682
# Best index: 2873, Best similarity: 0.7655164859750352
# Best index: 2542, Best similarity: 0.6644724292260766
# Best index: 1284, Best similarity: 0.7670763731002808
# Best index: 1443, Best similarity: 0.7714948654174805
# Best index: 2130, Best similarity: 0.6735347251812969
# Best index: 870, Best similarity: 0.8326948285102844
# Best index: 2349, Best similarity: 0.7317883842980142
# Best index: 1119, Best similarity: 0.6789131760597229
# Best index: 1407, Best similarity: 0.6737574338912964
# Best index: 2893, Best similarity: 0.8025011554296717
# Best index: 393, Best similarity: 0.9029442071914673
# Best index: 393, Best similarity: 0.9029442071914673
# Best index: 920, Best similarity: 0.7947817444801331
# Best index: 222, Best similarity: 0.779530942440033
# Best index: 222, Best similarity: 0.779530942440033
# Best index: 890, Best similarity: 0.8661521077156067
# Best index: 17, Best similarity: 0.8498537540435791
# Best index: 2279, Best similarity: 0.763191328481349
# Best index: 2794, Best similarity: 0.6366108137252859
# Best index: 2359, Best similarity: 0.8050395083976609
# Best index: 1359, Best similarity: 0.7437615990638733
# Best index: 2279, Best similarity: 0.763191328481349
# Best index: 895, Best similarity: 1.0
# Best index: 2864, Best similarity: 0.6650349462228723
# Best index: 1929, Best similarity: 0.7655663359935416
# Best index: 2767, Best similarity: 0.695061139995701
# Best index: 2907, Best similarity: 0.7506283780246008
# Best index: 2920, Best similarity: 0.6950246502070779
# Best index: 1617, Best similarity: 0.8137252300612392
# Best index: 1528, Best similarity: 0.8330519885317824
# Best index: 2859, Best similarity: 0.7598391035106483
# Best index: 1351, Best similarity: 0.7627186179161072
# Best index: 2911, Best similarity: 0.6128245769142757
# Best index: 1788, Best similarity: 0.9557942965142907
# Best index: 2780, Best similarity: 0.7234219084865348
# Best index: 1374, Best similarity: 0.7731631994247437
# Best index: 1218, Best similarity: 0.8339288830757141
# Best index: 2555, Best similarity: 0.8029735876790074
# Best index: 2851, Best similarity: 0.8489465643829353
# Best index: 2672, Best similarity: 0.6806580757759395
# Best index: 2221, Best similarity: 0.6698887015551045
# Best index: 263, Best similarity: 0.7462277412414551
# Best index: 2737, Best similarity: 0.6835127666169729
# Best index: 1135, Best similarity: 1.000000238418579
# Best index: 2920, Best similarity: 0.7526212364981502
# Best index: 213, Best similarity: 0.6783052682876587
# Best index: 2874, Best similarity: 0.8986035138024459
# Best index: 2079, Best similarity: 0.7174106842636219
# Best index: 2182, Best similarity: 0.7080829855073664
# Best index: 2818, Best similarity: 1.0000000000000004
# Best index: 641, Best similarity: 0.6611013412475586
# Best index: 1387, Best similarity: 0.9545103907585144
# Best index: 1957, Best similarity: 0.7088603241079288
# Best index: 1148, Best similarity: 0.7842787504196167
# Best index: 2869, Best similarity: 0.7907627672689161
# Best index: 2920, Best similarity: 0.7822127680918448
# Best index: 1851, Best similarity: 0.7031479050905807
# Best index: 2847, Best similarity: 0.643568759396085
# Best index: 2456, Best similarity: 0.6411532014700784
# Best index: 2879, Best similarity: 0.6577925259868214
# Best index: 2293, Best similarity: 0.6394740808458623
# Best index: 2879, Best similarity: 0.7277280490250976
# Best index: 888, Best similarity: 0.696662187576294
# Best index: 1164, Best similarity: 0.6455355882644653
# Best index: 2125, Best similarity: 0.7461925670823953
# Best index: 1767, Best similarity: 0.7078178433005118
# Best index: 1077, Best similarity: 0.7702850103378296
# Best index: 2599, Best similarity: 0.7089209619960296
# Best index: 1398, Best similarity: 0.6597623229026794
# Best index: 673, Best similarity: 0.874393880367279
# Best index: 2643, Best similarity: 0.65248827758308
# Best index: 1968, Best similarity: 0.672782289610328
# Best index: 890, Best similarity: 0.8367500305175781
# Best index: 890, Best similarity: 0.8367500305175781
# Best index: 0, Best similarity: 0.0
# Best index: 8, Best similarity: 0.8371337056159973
# Best index: 2847, Best similarity: 0.7020886159654389
# Best index: 2920, Best similarity: 0.7266644940325936
# Best index: 905, Best similarity: 0.6293084621429443
# Best index: 2276, Best similarity: 0.7794811420105257
# Best index: 346, Best similarity: 0.8302876949310303
# Best index: 350, Best similarity: 0.7696386575698853
# Best index: 2353, Best similarity: 0.8295912193295778
# Best index: 0, Best similarity: 1.000000238418579
# Best index: 2622, Best similarity: 0.8801680743679998
# Best index: 2893, Best similarity: 0.7129833611063731
# Best index: 894, Best similarity: 0.8144019842147827
# Best index: 24, Best similarity: 0.8130435943603516
# Best index: 1968, Best similarity: 0.6853114410606532
# Best index: 920, Best similarity: 0.7947817444801331
# Best index: 2920, Best similarity: 0.7121805012842364
# Best index: 2020, Best similarity: 0.7038356002437248
# Best index: 1687, Best similarity: 0.6306327815142951
# Best index: 1679, Best similarity: 0.6408111823124453
# Best index: 2766, Best similarity: 1.0000000000000007
# Best index: 2672, Best similarity: 0.6716654349584403
# Best index: 313, Best similarity: 0.7201046943664551
# Best index: 2346, Best similarity: 0.8050119211412783
# Best index: 1978, Best similarity: 0.663313092345587
# Best index: 27, Best similarity: 0.5841646194458008
# Best index: 1490, Best similarity: 0.7018180306983135
# Best index: 1398, Best similarity: 0.680920422077179
# Best index: 1295, Best similarity: 0.8264526724815369
# Best index: 1364, Best similarity: 0.665695071220398
# Best index: 2303, Best similarity: 0.6404914488625579
# Best index: 422, Best similarity: 0.7180138826370239
# Best index: 422, Best similarity: 0.7180138826370239
# Best index: 2873, Best similarity: 0.7296840843998051
# Best index: 1942, Best similarity: 0.8276062874971828
# Best index: 556, Best similarity: 0.6651731729507446
# Best index: 920, Best similarity: 0.7167513370513916
# Best index: 323, Best similarity: 0.8922752141952515
# Best index: 427, Best similarity: 0.6655533909797668
# Best index: 405, Best similarity: 0.9091522693634033
# Best index: 2879, Best similarity: 0.7076389980594656
# Best index: 2864, Best similarity: 0.7525345939416791
# Best index: 583, Best similarity: 0.6765345335006714
# Best index: 405, Best similarity: 0.9091522693634033
# Best index: 1383, Best similarity: 0.8316938877105713
# Best index: 1441, Best similarity: 0.8501901030540466
# Best index: 1617, Best similarity: 0.8598328585773626
# Best index: 1480, Best similarity: 0.7000839836283934
# Best index: 730, Best similarity: 0.752104640007019
# Best index: 1348, Best similarity: 0.6869138479232788
# Best index: 405, Best similarity: 0.9091522693634033
# Best index: 1424, Best similarity: 0.7543538808822632
# Best index: 1859, Best similarity: 0.762753416725232
# Best index: 2920, Best similarity: 0.7382812964174772
# Best index: 192, Best similarity: 0.7534837126731873
# Best index: 196, Best similarity: 0.632615327835083
# Best index: 1988, Best similarity: 0.7049926529166437
# Best index: 1535, Best similarity: 0.7906853036022459
# Best index: 2120, Best similarity: 0.7514566944467751
# Best index: 328, Best similarity: 0.847646951675415
# Best index: 2676, Best similarity: 0.807522156817235
# Best index: 787, Best similarity: 0.788638174533844
# Best index: 1374, Best similarity: 0.7786009311676025
# Best index: 2029, Best similarity: 0.7672606865435996
# Best index: 196, Best similarity: 0.6261031627655029
# Best index: 534, Best similarity: 0.9077434539794922
# Best index: 2656, Best similarity: 0.7734718026436403
# Best index: 2239, Best similarity: 0.6498320566744362
# Best index: 541, Best similarity: 0.8084558248519897
# Best index: 1203, Best similarity: 0.8102831244468689
# Best index: 2607, Best similarity: 0.7648600938471108
# Best index: 2907, Best similarity: 0.6439280767045183
# Best index: 45, Best similarity: 0.6776362657546997
# Best index: 939, Best similarity: 0.7280004620552063
# Best index: 2914, Best similarity: 0.8001106737623631
# Best index: 1448, Best similarity: 0.7451768517494202
# Best index: 2361, Best similarity: 0.7057122601961568
# Best index: 2361, Best similarity: 0.7057122601961568
# Best index: 111, Best similarity: 0.8248294591903687
# Best index: 1085, Best similarity: 0.603824257850647
# Best index: 2891, Best similarity: 0.6070861112363557
# Best index: 2699, Best similarity: 0.840281602959801
# Best index: 1947, Best similarity: 0.7860841196519792
# Best index: 2510, Best similarity: 0.8578032864773854
# Best index: 1030, Best similarity: 0.8016889095306396
# Best index: 2680, Best similarity: 0.8090695132173673
# Best index: 534, Best similarity: 0.9077434539794922
# Best index: 534, Best similarity: 0.9077434539794922
# Best index: 2594, Best similarity: 0.7703661581719857
# Best index: 2679, Best similarity: 0.7411627789723325
# Best index: 1403, Best similarity: 0.7543134093284607
# Best index: 168, Best similarity: 0.6759473085403442
# Best index: 1933, Best similarity: 0.8182899925823972
# Best index: 772, Best similarity: 0.7912284135818481
# Best index: 2072, Best similarity: 0.838469796403218
# Best index: 1205, Best similarity: 0.8446158170700073
# Best index: 1592, Best similarity: 0.6487273880910112
# Best index: 290, Best similarity: 0.7264575958251953
# Best index: 1641, Best similarity: 0.8251997191103339
# Best index: 2542, Best similarity: 0.9026731126959697
# Best index: 894, Best similarity: 0.7468627691268921
# Best index: 393, Best similarity: 0.9029442071914673
# Best index: 1434, Best similarity: 0.8436096906661987
# Best index: 2599, Best similarity: 0.7297604650070786
# Best index: 1078, Best similarity: 0.6950453519821167
# Best index: 2353, Best similarity: 0.7252420647667397
# Best index: 2029, Best similarity: 0.6693890228887821
# Best index: 2680, Best similarity: 0.762116996227877
# Best index: 1341, Best similarity: 0.7513087391853333
# Best index: 1443, Best similarity: 0.8198162913322449
# Best index: 1833, Best similarity: 0.6809927122835484
# Best index: 2815, Best similarity: 1.0000000000000009
# Best index: 2679, Best similarity: 0.6480934926476849
# Best index: 1433, Best similarity: 0.6371563673019409
# Best index: 1942, Best similarity: 0.8276062874971828
# Best index: 1579, Best similarity: 0.821438829888024
# Best index: 138, Best similarity: 0.6464976072311401
# Best index: 1545, Best similarity: 0.6463064929573181
# Best index: 2920, Best similarity: 0.7266644940325936
# Best index: 53, Best similarity: 0.6838173866271973
# Best index: 898, Best similarity: 0.6629083156585693
# Best index: 2326, Best similarity: 0.7806627670977737
# Best index: 2380, Best similarity: 0.7975966694336061
# Best index: 1443, Best similarity: 0.7107423543930054
# Best index: 1439, Best similarity: 0.7157837748527527
# Best index: 1455, Best similarity: 0.8669750094413757
# Best index: 820, Best similarity: 0.6857373118400574
# Best index: 2435, Best similarity: 0.7564342677750017
# Best index: 2912, Best similarity: 0.6456344070331674
# Best index: 2155, Best similarity: 0.7789350798331807
# Best index: 1813, Best similarity: 0.7082111720202123
# Best index: 679, Best similarity: 0.7287744283676147
# Best index: 1876, Best similarity: 0.841443763009809
# ...
# Best index: 1138, Best similarity: 0.7348970174789429
# Best index: 2805, Best similarity: 0.6727988091600265
# Best index: 2305, Best similarity: 0.7295135958501917
# Best index: 1287, Best similarity: 0.7551806569099426
# Best index: 1096, Best similarity: 0.7405194044113159
# Best index: 2542, Best similarity: 0.9026731126959697
# Best index: 2846, Best similarity: 0.6710704434501302
# Best index: 1416, Best similarity: 0.8651577234268188
# Best index: 2879, Best similarity: 0.7048880795930835
# Best index: 2843, Best similarity: 0.8123822332816926
# Best index: 890, Best similarity: 0.7562654614448547
# Best index: 2841, Best similarity: 0.607793279234456
# Best index: 2113, Best similarity: 0.6350780323907521
# Best index: 1288, Best similarity: 0.6068680286407471
# Best index: 2629, Best similarity: 0.7055633525043699
# Best index: 2064, Best similarity: 0.7327268929205153
# Best index: 2893, Best similarity: 0.8532538157491492
# Best index: 2159, Best similarity: 0.7378856101707297
# Best index: 2542, Best similarity: 0.7229875569690983
# Best index: 612, Best similarity: 0.6206628680229187
# Best index: 2704, Best similarity: 0.840888680255816
# Best index: 891, Best similarity: 0.8194373846054077
# Best index: 1847, Best similarity: 0.7356458709326249
# Best index: 263, Best similarity: 0.7462277412414551
# Best index: 2159, Best similarity: 0.7378856101707297
# Best index: 2320, Best similarity: 0.7613079891613267
# Best index: 1312, Best similarity: 0.7601094245910645
# Best index: 2864, Best similarity: 0.7338649534872451
# Best index: 2893, Best similarity: 0.7079690197412453
# Best index: 2892, Best similarity: 0.7396835901700548
# Best index: 890, Best similarity: 0.7270952463150024
# Best index: 1434, Best similarity: 0.842519998550415
# Best index: 679, Best similarity: 0.7290698289871216
# Best index: 897, Best similarity: 0.5787410140037537
# Best index: 2879, Best similarity: 0.6901957326923182
# Best index: 1470, Best similarity: 0.6584721906965932
# Best index: 177, Best similarity: 0.7678121328353882
# Best index: 2237, Best similarity: 0.6860024411595302
# Best index: 1605, Best similarity: 0.6462282884169321
# Best index: 2594, Best similarity: 0.6491950229946484
# Best index: 2778, Best similarity: 1.0000000000000009
# Best index: 775, Best similarity: 0.6820453405380249
# Best index: 1354, Best similarity: 0.8243093490600586
# Best index: 2354, Best similarity: 0.6752340541660689
# Best index: 2922, Best similarity: 0.6398692812236149
# Best index: 1407, Best similarity: 0.7245567440986633
# Best index: 1416, Best similarity: 0.758468747138977
# Best index: 457, Best similarity: 0.808419942855835
# Best index: 1431, Best similarity: 0.6940234303474426
# Best index: 885, Best similarity: 0.7661715745925903
# Best index: 919, Best similarity: 0.8911346793174744
# Best index: 538, Best similarity: 0.654683530330658
# Best index: 2600, Best similarity: 0.7999190516853408
# Best index: 2737, Best similarity: 1.0000000000000004
# Best index: 2879, Best similarity: 0.7758011026818956
# Best index: 608, Best similarity: 0.8380210995674133
# Best index: 2820, Best similarity: 0.686742830800541
# Best index: 266, Best similarity: 0.6656631231307983
# Best index: 1661, Best similarity: 0.769391083687623
# Best index: 2357, Best similarity: 0.8844833115761548
# Best index: 2900, Best similarity: 0.7890985420360659
# Best index: 2585, Best similarity: 0.7984488690645433
# Best index: 2352, Best similarity: 0.602145697006265
# Best index: 2356, Best similarity: 0.8806077221312294
# Best index: 0, Best similarity: 0.0
# Best index: 1489, Best similarity: 0.7652497107943745
# Best index: 2545, Best similarity: 0.6687235891054046
# Best index: 870, Best similarity: 0.9062776565551758
# Best index: 1076, Best similarity: 0.7926021814346313
# Best index: 408, Best similarity: 0.7694644927978516
# Best index: 1792, Best similarity: 0.7372451314515567
# Best index: 1064, Best similarity: 0.827721893787384
# Best index: 2357, Best similarity: 0.8591076559110048
# Best index: 2672, Best similarity: 0.6796693854319003
# Best index: 1928, Best similarity: 0.8142728553363308
# Best index: 2777, Best similarity: 0.7123526523449175
# Best index: 1106, Best similarity: 0.8775348663330078
# Best index: 1098, Best similarity: 0.6964153051376343
# Best index: 1266, Best similarity: 0.7143764495849609
# Best index: 2907, Best similarity: 0.653801794124016
# Best index: 21, Best similarity: 0.7284624576568604
# Best index: 2533, Best similarity: 0.835332013681366
# Best index: 1365, Best similarity: 0.7341011762619019
# Best index: 2889, Best similarity: 0.8722393014580377
# Best index: 1617, Best similarity: 0.8340562529650966
# Best index: 2093, Best similarity: 0.7396331929410577
# Best index: 2349, Best similarity: 0.7502921122580056
# Best index: 1443, Best similarity: 0.6860524415969849
# Best index: 2079, Best similarity: 0.7174106842636219
# Best index: 2838, Best similarity: 0.8291909202880474
# Best index: 2542, Best similarity: 0.9187102103871663
# Best index: 1138, Best similarity: 0.7348970174789429
# Best index: 2726, Best similarity: 0.977072820509627
# Best index: 2627, Best similarity: 0.7356043465637624
# Best index: 842, Best similarity: 0.8489289879798889
# Best index: 1429, Best similarity: 0.6844760775566101
# Best index: 17, Best similarity: 0.8556444644927979
# Best index: 1492, Best similarity: 1.0000000000000018
# Best index: 1808, Best similarity: 0.6026599900736934
# Best index: 1156, Best similarity: 0.7607806921005249
# Best index: 2541, Best similarity: 0.7113492474565333
# Best index: 591, Best similarity: 0.6913367509841919
# Best index: 2528, Best similarity: 0.7184652271048693
# Best index: 1284, Best similarity: 0.7256539463996887
# Best index: 2869, Best similarity: 0.809052896701925
# Best index: 1968, Best similarity: 0.7046432074931992
# Best index: 1122, Best similarity: 0.7016389966011047
# Best index: 1033, Best similarity: 0.7153730392456055
# Best index: 2720, Best similarity: 0.6779587808838463
# Best index: 917, Best similarity: 0.7110128402709961
# Best index: 2919, Best similarity: 0.9188142422757224
# Best index: 1429, Best similarity: 0.7577855587005615
# Best index: 557, Best similarity: 0.6404967904090881
# Best index: 864, Best similarity: 0.7341749668121338
# Best index: 1944, Best similarity: 0.6974989321449497
# Best index: 2829, Best similarity: 0.8021650839230015
# Best index: 1450, Best similarity: 0.8133254051208496
# Best index: 894, Best similarity: 0.8277910947799683
# Best index: 351, Best similarity: 1.000000238418579
# Best index: 1991, Best similarity: 0.6920619356572623
# Best index: 1593, Best similarity: 0.6512566946543856
# Best index: 2903, Best similarity: 0.6712886888445664
# Best index: 827, Best similarity: 0.714762806892395
# Best index: 1946, Best similarity: 0.6476306612391692
# Best index: 894, Best similarity: 0.6666737198829651
# Best index: 1098, Best similarity: 0.8191640973091125
# Best index: 2918, Best similarity: 0.6782824583494758
# Best index: 1443, Best similarity: 0.6860524415969849
# Best index: 1492, Best similarity: 0.7032403820356159
# Best index: 559, Best similarity: 0.6985852718353271
# Best index: 2354, Best similarity: 0.7843839186724617
# Best index: 2875, Best similarity: 0.7324837504072059
# Best index: 2373, Best similarity: 0.6323007189400462
# Best index: 2373, Best similarity: 0.6323007189400462
# Best index: 0, Best similarity: 0.0
# Best index: 1284, Best similarity: 0.9748111367225647
# Best index: 1994, Best similarity: 0.7024138796158882
# Best index: 330, Best similarity: 0.7125177383422852
# Best index: 2920, Best similarity: 0.676545723765323
# Best index: 919, Best similarity: 0.8175774812698364
# Best index: 122, Best similarity: 0.6765124201774597
# Best index: 0, Best similarity: 0.0
# Best index: 113, Best similarity: 1.0
# Best index: 2016, Best similarity: 0.7394066105561474
# Best index: 1047, Best similarity: 0.8492566347122192
# Best index: 2893, Best similarity: 0.6175642964264645
# Best index: 2243, Best similarity: 0.6838672098772637
# Best index: 1078, Best similarity: 0.9243674278259277
# Best index: 2381, Best similarity: 0.6623899622001826
# Best index: 298, Best similarity: 0.6860668063163757
# Best index: 2600, Best similarity: 0.8116713406288056
# Best index: 1429, Best similarity: 0.6466975808143616
# Best index: 2380, Best similarity: 0.7018746696484777
# Best index: 1621, Best similarity: 1.0000000000000009
# Best index: 1523, Best similarity: 0.6418461286562795
# Best index: 811, Best similarity: 0.7268328070640564
# Best index: 1794, Best similarity: 0.6792936895202027
# Best index: 228, Best similarity: 0.696690559387207
# Best index: 2351, Best similarity: 1.0000000000000013
# Best index: 2361, Best similarity: 0.669627474504979
# Best index: 2043, Best similarity: 0.6398380956400678
# Best index: 337, Best similarity: 0.7650694847106934
# Best index: 893, Best similarity: 1.0
# Best index: 1450, Best similarity: 0.7170472145080566
# Best index: 1884, Best similarity: 0.6395295002059045
# Best index: 2879, Best similarity: 0.7512293185592225
# Best index: 2893, Best similarity: 0.7105354581935907
# Best index: 2920, Best similarity: 0.7266644940325936
# Best index: 1972, Best similarity: 0.862721457528576
# Best index: 0, Best similarity: 0.0
# Best index: 391, Best similarity: 0.7383655309677124
# Best index: 1944, Best similarity: 0.6149205958239634
# Best index: 2625, Best similarity: 0.9213722604129934
# Best index: 1968, Best similarity: 0.7126064533661857
# Best index: 2675, Best similarity: 0.8287787649484065
# Best index: 1397, Best similarity: 0.7830117344856262
# Best index: 2156, Best similarity: 0.713730164201005
# Best index: 1665, Best similarity: 0.6161131152528545
# Best index: 129, Best similarity: 0.6544629335403442
# Best index: 547, Best similarity: 0.6541236042976379
# Best index: 919, Best similarity: 0.7368714809417725
# Best index: 1592, Best similarity: 0.7296278837900203
# Best index: 1833, Best similarity: 0.6429923733187726
# Best index: 459, Best similarity: 0.898499608039856
# Best index: 2401, Best similarity: 0.7432223470674628
# Best index: 1695, Best similarity: 0.597388007004698
# Best index: 2359, Best similarity: 0.8808432237543077
# Best index: 2012, Best similarity: 0.6780778891229163
# Best index: 1335, Best similarity: 0.7254983186721802
# Best index: 1217, Best similarity: 0.7508955001831055
# Best index: 24, Best similarity: 0.7467193603515625
# Best index: 2627, Best similarity: 0.794767325639419
# Best index: 1357, Best similarity: 0.8907276391983032
# Best index: 1214, Best similarity: 1.0
# Best index: 1147, Best similarity: 1.0
# Best index: 2237, Best similarity: 0.7849017016638891
# Best index: 2237, Best similarity: 0.7849017016638891
# Best index: 129, Best similarity: 0.6387311220169067
# Best index: 1434, Best similarity: 0.8436096906661987
# Best index: 1068, Best similarity: 0.752856969833374
# Best index: 2921, Best similarity: 0.6482062617146344
# Best index: 2921, Best similarity: 0.6482062617146344
# Best index: 1403, Best similarity: 0.8311635851860046
# Best index: 2598, Best similarity: 0.7233468961809336
# Best index: 2752, Best similarity: 0.7135979899041129
# Best index: 2079, Best similarity: 0.6753271338586176
# Best index: 1411, Best similarity: 0.8020744919776917
# Best index: 1411, Best similarity: 0.8020744919776917
# Best index: 1214, Best similarity: 0.7275787591934204
# Best index: 2767, Best similarity: 0.7839939953545209
# Best index: 919, Best similarity: 0.8175774812698364
# Best index: 1833, Best similarity: 0.6818966286083659
# Best index: 2750, Best similarity: 0.6934054307340947
# Best index: 890, Best similarity: 0.7784566879272461
# Best index: 168, Best similarity: 0.8034932613372803
# Best index: 2540, Best similarity: 0.7377338997582695
# Best index: 2476, Best similarity: 0.747292814821839
# Best index: 1569, Best similarity: 0.7139637147348383
# Best index: 2351, Best similarity: 1.0000000000000013
# Best index: 1443, Best similarity: 0.7450143098831177
# Best index: 2622, Best similarity: 0.813842975978319
# Best index: 2842, Best similarity: 0.699469284338631
# Best index: 279, Best similarity: 0.7636433839797974
# Best index: 148, Best similarity: 0.7207536697387695
# Best index: 49, Best similarity: 0.8291245698928833
# Best index: 298, Best similarity: 0.7052662372589111
# Best index: 1484, Best similarity: 0.8333223348296255
# Best index: 2358, Best similarity: 0.6357165844111207
# Best index: 2919, Best similarity: 0.8319502254670601
# Best index: 463, Best similarity: 0.8611602783203125
# Best index: 1441, Best similarity: 0.9285337328910828
# Best index: 1377, Best similarity: 0.72413170337677
# Best index: 1569, Best similarity: 0.7485875664986352
# Best index: 1645, Best similarity: 0.6435835222424826
# Best index: 0, Best similarity: 0.0
# Best index: 1569, Best similarity: 0.7139637147348383
# Best index: 128, Best similarity: 0.6864460706710815
# Best index: 405, Best similarity: 0.8635793924331665
# Best index: 1076, Best similarity: 0.7926021814346313
# Best index: 1280, Best similarity: 0.62031090259552
# Best index: 1435, Best similarity: 0.718055784702301
# Best index: 2920, Best similarity: 0.6601915597193526
# Best index: 2120, Best similarity: 0.7514566944467751
# Best index: 2357, Best similarity: 0.6776565852785599
# Best index: 2864, Best similarity: 0.6442047432985116
# Best index: 2823, Best similarity: 0.6637191035903587
# Best index: 2353, Best similarity: 0.6726825446390012
# Best index: 2907, Best similarity: 0.887110441154364
# Best index: 364, Best similarity: 0.6893826127052307
# Best index: 917, Best similarity: 0.6951666474342346
# Best index: 770, Best similarity: 0.666141152381897
# Best index: 2598, Best similarity: 0.7233468961809336
# Best index: 2598, Best similarity: 0.7233468961809336
# Best index: 2893, Best similarity: 0.7754862322480809
# Best index: 149, Best similarity: 0.6510815024375916
# Best index: 2236, Best similarity: 0.6904367620257316
# Best index: 2750, Best similarity: 0.7224892715884531
# Best index: 2698, Best similarity: 0.7490737260718994
# Best index: 2705, Best similarity: 0.7603754746378996
# Matching process completed and saved to Excel.
#                                       activity  \
# 2                                     TOURISME
# 3                                 Garde malade
# 5                       Development commercial
# 6     Conseiller en hôtellerie et du tourisme.
# 8                               conducteur VTC
# ...                                        ...
# 3389                               تنضيف منازل
# 3397     Plomberie sanitaire chauffage central
# 3398  Transport est livraison est déménagement
# 3399        Emballage des aliments et des noix
# 3403              Menuiseries aluminium et pvc
#
#                                        matched_activity  \
# 2                  Conseiller en hôtellerie et tourisme
# 3                                          Garde malade
# 5                               Représentant commercial
# 6                  Conseiller en hôtellerie et tourisme
# 8     Chauffeur VTC (voiture de transport avec chauf...
# ...                                                 ...
# 3389                              Ongleriste à domicile
# 3397             Technicien de maintenance en chauffage
# 3398  Chargé(e) de la logistique d'une entreprise de...
# 3399                                 Designer packaging
# 3403                       Menuisier en décor spectacle
#
#                     matched_activity_ar  matched_code
# 2            مستشار في الفندقة والسياحة       10121.0
# 3                  مساعد الرعاية الصحية       10202.0
# 5                          مندوب مبيعات       10306.0
# 6            مستشار في الفندقة والسياحة       10121.0
# 8          سائق VTC (سيارة نقل مع سائق)       30904.0
# ...                                 ...           ...
# 3389  أخصائي(ة) تجميل الأظافر في المنزل       10129.0
# 3397              تقني صيانة في التدفئة       63703.0
# 3398     مكلف باللوجستيات في شركة توصيل       40101.0
# 3399          مصمم الأغلفة وعلب التعبئة       61103.0
# 3403                   نجار ديكور العرض       71215.0
#
# [1403 rows x 4 columns]
# Matched activities saved to: /content/drive/My Drive/hackathon1/matched_activities_only.xlsx
# Unmatched activities saved to: /content/drive/My Drive/hackathon1/not_matched_activities.xlsx

# %%
import pandas as pd
from sentence_transformers import SentenceTransformer, util

# Load a multilingual model for embeddings
model = SentenceTransformer("Alibaba-NLP/gte-multilingual-base", trust_remote_code=True)

# Lists of traditional commercial activities (to exclude)
traditional_commercial_activities = [
    "restaurant", "vente", "achat", "café", "fast food", "boucherie", "poissonnerie", "téléphone",
    "bijouterie", "magasin", "boutique", "fournisseur", "détaillant", "grossiste", "revendeur",
    "importateur", "exportateur", "franchise", "vendeur", "commerçant", "négoce", "dépôt vente",
    "magasin alimentaire", "produits alimentaires", "produits de consommation", "liquidation",
    "bazar", "marché", "vente de voitures", "agents commerciaux", "services de livraison",
    "construction", "matériel de construction", "équipement industriel", "téléphonie mobile", "réparation",
    "location", "distribution", "importation", "commerce de détail", "distributeur", "commerçant de proximité",
    "agricole", "produits agricoles", "alimentation générale", "commerçant ambulant", "transports",
    "مطعم", "بيع", "شراء", "مقهى", "وجبات سريعة", "جزارة", "سمك", "هاتف", "مجوهرات", "متجر", "دكان",
    "مورد", "تاجر تجزئة", "تاجر جملة", "بائع", "مستورد", "مُصدر", "امتياز", "تجارة", "بيع بالتجزئة",
    "منتجات غذائية", "منتجات استهلاكية", "تصفية", "بازار", "سوق", "بيع السيارات", "وكلاء تجاريين",
    "خدمات التوصيل", "إنشاء", "معدات البناء", "تجهيزات صناعية", "هواتف محمولة", "صيانة", "إيجار",
    "توزيع", "استيراد", "تجارة التجزئة", "موزع", "تاجر محلي", "زراعي", "منتجات زراعية", "تجارة عامة",
    "تاجر متجول", "نقل"
]

# Allowed e-commerce & intermediary activities (to keep)
ecommerce_intermediary_activities = [
    "e-commerce", "plateforme de vente", "e-shop", "site marchand", "marketplace", "dropshipping",
    "affiliation", "vente en ligne", "webshop", "commerce virtuel", "commerce digital", "fournisseur e-commerce",
    "commerce électronique", "start-up", "entrepreneur digital", "services de paiement", "agent commercial",
    "courtier", "publicité en ligne", "consultant", "services en ligne", "freelance", "plateforme de freelancing",
    "commercialisation", "digital marketing", "plateforme B2B", "réseau de distribution",
    "تجارة إلكترونية", "منصة بيع", "متجر إلكتروني", "موقع تجاري", "سوق إلكتروني", "دروبشيبينغ",
    "تسويق بالعمولة", "متجر على الإنترنت", "تجارة افتراضية", "تجارة رقمية", "مورد تجارة إلكترونية",
    "شركة ناشئة", "ريادي رقمي", "خدمات الدفع", "وكيل تجاري", "سمسار", "إعلانات عبر الإنترنت",
    "مستشار", "خدمات عبر الإنترنت", "مستقل", "منصة عمل مستقل", "تسويق", "تسويق رقمي", "إدارة الحملات",
    "منصة إعلانات", "تسويق بالعمولة", "وسيط", "وكيل مبيعات", "حلول رقمية", "تخزين سحابي", "دعم العملاء",
    "إعلانات رقمية", "وسائل التواصل الاجتماعي", "منصة بي تو بي", "شبكة توزيع"
]

# Normalize activity lists
traditional_commercial_activities = [normalize_text(act) for act in traditional_commercial_activities]
ecommerce_intermediary_activities = [normalize_text(act) for act in ecommerce_intermediary_activities]

# Encode reference lists
embeddings_commercial = model.encode(traditional_commercial_activities, convert_to_tensor=True)
embeddings_ecommerce = model.encode(ecommerce_intermediary_activities, convert_to_tensor=True)

# Function to determine if an activity is traditional commercial
def classify_activity(activity_text):
    if pd.isna(activity_text):
        return False

    activity_embedding = model.encode(activity_text, convert_to_tensor=True)

    # Compute similarity scores
    similarity_commercial = util.cos_sim(activity_embedding, embeddings_commercial).max().item()
    similarity_ecommerce = util.cos_sim(activity_embedding, embeddings_ecommerce).max().item()

    # Threshold-based filtering
    if similarity_commercial > 0.7 and similarity_commercial > similarity_ecommerce:
        return True  # Exclude (Traditional Commercial)

    return False  # Keep (E-commerce / Valid Activity)

# Apply filtering
df_not_matched['is_traditional_commercial'] = df_not_matched['activity'].apply(classify_activity)

# Separate valid and removed activities
df_valid_activities = df_not_matched[df_not_matched['is_traditional_commercial'] == False].drop(columns=['is_traditional_commercial'])
df_removed_activities = df_not_matched[df_not_matched['is_traditional_commercial'] == True].drop(columns=['is_traditional_commercial'])

# Save filtered datasets
valid_activities_file = "/content/drive/My Drive/hackathon1/final_filtered_non_commercial.xlsx"
removed_activities_file = "/content/drive/My Drive/hackathon1/removed_commercial_activities.xlsx"

df_valid_activities.to_excel(valid_activities_file, index=False)
df_removed_activities.to_excel(removed_activities_file, index=False)

print(f"✅ Final filtered non-commercial & e-commerce activities saved to: {valid_activities_file}")
print(f"❌ Removed traditional commercial activities saved to: {removed_activities_file}")
# Out:
# Some weights of the model checkpoint at Alibaba-NLP/gte-multilingual-base were not used when initializing NewModel: {'classifier.weight', 'classifier.bias'}
# - This IS expected if you are initializing NewModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing NewModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# <ipython-input-29-28a044a62975>:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_not_matched['is_traditional_commercial'] = df_not_matched['activity'].apply(classify_activity)
# ✅ Final filtered non-commercial & e-commerce activities saved to: /content/drive/My Drive/hackathon1/final_filtered_non_commercial.xlsx
# ❌ Removed traditional commercial activities saved to: /content/drive/My Drive/hackathon1/removed_commercial_activities.xlsx
